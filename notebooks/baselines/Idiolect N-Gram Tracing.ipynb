# %% [markdown]
# # Run N-Gram Tracing Using Idiolect
#
# This notebook runs the idiolect n-gram tracing methods to get scores ready to plug into the performance functions. These are to be used as a baseline for the logprobs method.

# %%
# library(devtools)

# installs from the local folder (your modified clone)
# devtools::install("/Users/user/Documents/GitHub/idiolect", upgrade = "never")

# %%
if (requireNamespace("idiolect", quietly = TRUE)) {
  message("Removing Installed Version of Idiolect")
  invisible(capture.output(remove.packages("idiolect")))
}

message("Installing CRAN Version of Idiolect")
invisible(capture.output(install.packages("idiolect", quiet = TRUE)))
# Out:
# Removing Installed Version of Idiolect
# Removing package from ‘/Library/Frameworks/R.framework/Versions/4.2-arm64/Resources/library’
# (as ‘lib’ is unspecified)
# Warning messages:
# 1: In .recacheSubclasses(def@className, def, env) :
#   undefined subclass "ndiMatrix" of class "replValueSp"; definition not updated
# 2: In .recacheSubclasses(def@className, def, env) :
#   undefined subclass "pcorMatrix" of class "replValueSp"; definition not updated
# Installing CRAN Version of Idiolect
# installing the source package ‘idiolect’

# %%
suppressWarnings(
  suppressPackageStartupMessages(
    {
      library(writexl)
      library(idiolect)
      library(readxl)
      library(dplyr)
    }
  )
)

# %%
source("../../src/R_functions.R")

# %%
run_ngram_tracing_save_progress <- function(
  metadata, known, unknown,
  tokens = "word",
  n = 1,
  coefficient = NULL,
  out_path,
  save_every = 10,
  quiet = TRUE
) {
  #' Function to run n-gram tracing pricess across a metadata dataframe and save it to an Excel file.
  #' It also combines various bits of metadata to the results from the dataframe.
  #' 
  #' params
  #' metadata: The metadata dataframe
  #' known: The known dataframe
  #' unknown: The unknown dataframe
  #' tokens: The type of n-gram tokens to use (defaults to 'word')
  #' n: The n-gram level (defaults to 1)
  #' coefficient: The coefficient from the n-gram tracing function (defaults to None a.k.a. simpson)
  #' out_path: a location to save to
  #' save_every: After how many rows of the metadata should we save (defaults to 10)
  #' quiet: Run the funciton without updates (defaults to TRUE)

  message("Saving to: ", out_path)

  results_list <- vector("list", nrow(metadata))
  out_i <- 0L

  for (i in seq_len(nrow(metadata))) {
    selected_problem <- metadata[i, , drop = FALSE]

    k  <- as.character(selected_problem$known_author)
    u  <- as.character(selected_problem$unknown_author)
    c_ <- as.character(selected_problem$corpus)

    known_subset   <- quanteda::corpus_subset(known, corpus == c_ & author == k)
    unknown_subset <- quanteda::corpus_subset(unknown, corpus == c_ & author == u)

    if (quanteda::ndoc(known_subset) == 0 || quanteda::ndoc(unknown_subset) == 0) {
      out_i <- out_i + 1L
      selected_problem$n <- n
      selected_problem$target <- NA
      selected_problem$score <- NA
      results_list[[out_i]] <- selected_problem
      next
    }

    one_res <- tryCatch({
      run_call <- function() ngram_tracing(
        unknown_subset, known_subset,
        tokens = tokens, n = n,
        remove_punct = FALSE, remove_symbols = FALSE, remove_numbers = FALSE,
        coefficient = coefficient
      )

      tracing_raw <- if (quiet) suppressMessages(suppressWarnings(run_call())) else run_call()

      if (is.data.frame(tracing_raw)) {
        if (all(c("target","score") %in% names(tracing_raw))) {
          tr <- tracing_raw[, c("target","score"), drop = FALSE]
        } else if (ncol(tracing_raw) >= 2) {
          tr <- tracing_raw[, 1:2, drop = FALSE]
          names(tr) <- c("target","score")
        } else {
          tr <- data.frame(target = NA, score = NA)
        }
      } else if (is.list(tracing_raw) && !is.null(tracing_raw$target) && !is.null(tracing_raw$score)) {
        tr <- data.frame(target = tracing_raw$target, score = tracing_raw$score)
      } else {
        tr <- data.frame(target = NA, score = NA)
      }

      meta_rep <- selected_problem[rep(1, nrow(tr)), , drop = FALSE]
      cbind(meta_rep, coefficient = coefficient, n = n, tr)

    }, error = function(e) {
      message("Row ", i, " FAILED: ", conditionMessage(e))
      selected_problem$n <- n
      selected_problem$target <- NA
      selected_problem$score <- NA
      selected_problem
    })

    out_i <- out_i + 1L
    results_list[[out_i]] <- one_res

    if (i %% save_every == 0) {
      snapshot <- do.call(rbind, results_list[seq_len(out_i)])
      rownames(snapshot) <- NULL
      writexl::write_xlsx(list(results = snapshot), out_path)
      message("  (snapshot saved at row ", i, ")")
    }
  }

  final_df <- do.call(rbind, results_list[seq_len(out_i)])
  rownames(final_df) <- NULL
  writexl::write_xlsx(list(results = final_df), out_path)
  message("Done. Final saved: ", out_path)

  invisible(final_df)
}

# %%
run_ngram_tracing_for_n_values <- function(
  metadata, known, unknown,
  n_values = 1:10,
  out_dir,
  file_prefix = "ngram_tracing_results_simpson_",
  save_every = 10,
  quiet = TRUE,
  tokens = "word",
  coefficient = "simpson",
  skip_if_exists = TRUE
) {
  #' Function to run the n-gram tracing function over a range of n. Saving individual files.
  #' 
  #' 
  if (!dir.exists(out_dir)) dir.create(out_dir, recursive = TRUE)

  pad_width <- nchar(as.character(max(n_values)))

  for (n in n_values) {
    n_str <- sprintf(paste0("%0", pad_width, "d"), n)
    out_path <- file.path(out_dir, paste0(file_prefix, n_str, ".xlsx"))

    if (skip_if_exists && file.exists(out_path)) {
      message("Skipping n = ", n, " (exists): ", out_path)
      next
    }

    message("==== n = ", n, " -> ", out_path, " ====")

    tryCatch({
      run_ngram_tracing_save_progress(
        metadata = metadata,
        known = known,
        unknown = unknown,
        n = n,
        out_path = out_path,
        save_every = save_every,
        quiet = quiet,
        tokens = tokens,
        coefficient = coefficient
      )
    }, error = function(e) {
      message("FAILED n = ", n, " : ", conditionMessage(e))
      invisible(NULL)
    })
  }

  invisible(TRUE)
}

# %%
base_read_loc <- "/Volumes/BCross/datasets/author_verification"
base_save_loc <- "/Volumes/BCross/av_datasets_experiments/Baseline Results"

data_types <- c("test", "training")

corpora <- c("Wiki", "Enron", "Perverted Justice", "StackExchange",
            "ACL", "TripAdvisor", "The Apricity", "Koppel's Blogs",
            "The Telegraph", "Reddit")

for(d_type in data_types){

  known <- readRDS(file.path(base_read_loc, d_type, "known_raw.rds"))
  unknown <- readRDS(file.path(base_read_loc, d_type, "unknown_raw.rds"))
  metadata <- readRDS(file.path(base_read_loc, d_type, "metadata.rds"))

  coefs <- c("simpson", "jaccard")

  for(corp in corpora) {

    metadata_corpus <- metadata %>%
      dplyr::filter(corpus == corp)

    out_dir <- file.path(base_save_loc, d_type, corp, "n_gram_tracing")

    dir.create(out_dir, recursive = TRUE, showWarnings = FALSE)

    for(co in coefs){
      print(paste0("Working on Corpus: ", corp, " with Metric: ", co))

      run_ngram_tracing_for_n_values(
      metadata_corpus, known, unknown,
      n_values = 2:10,
      out_dir=out_dir,
      file_prefix = paste0("ngram_tracing_results_", co, "_"),
      save_every = 10,
      quiet = TRUE,
      tokens = "word",
      coefficient = co,
      skip_if_exists = TRUE
      )
    }
  }
}
# Out:
# [1] "Working on Corpus: Wiki with Metric: simpson"
# Skipping n = 2 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Wiki/n_gram_tracing/ngram_tracing_results_simpson_02.xlsx
# Skipping n = 3 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Wiki/n_gram_tracing/ngram_tracing_results_simpson_03.xlsx
# Skipping n = 4 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Wiki/n_gram_tracing/ngram_tracing_results_simpson_04.xlsx
# Skipping n = 5 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Wiki/n_gram_tracing/ngram_tracing_results_simpson_05.xlsx
# Skipping n = 6 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Wiki/n_gram_tracing/ngram_tracing_results_simpson_06.xlsx
# Skipping n = 7 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Wiki/n_gram_tracing/ngram_tracing_results_simpson_07.xlsx
# Skipping n = 8 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Wiki/n_gram_tracing/ngram_tracing_results_simpson_08.xlsx
# Skipping n = 9 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Wiki/n_gram_tracing/ngram_tracing_results_simpson_09.xlsx
# Skipping n = 10 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Wiki/n_gram_tracing/ngram_tracing_results_simpson_10.xlsx
# [1] "Working on Corpus: Wiki with Metric: jaccard"
# Skipping n = 2 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Wiki/n_gram_tracing/ngram_tracing_results_jaccard_02.xlsx
# Skipping n = 3 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Wiki/n_gram_tracing/ngram_tracing_results_jaccard_03.xlsx
# Skipping n = 4 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Wiki/n_gram_tracing/ngram_tracing_results_jaccard_04.xlsx
# Skipping n = 5 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Wiki/n_gram_tracing/ngram_tracing_results_jaccard_05.xlsx
# Skipping n = 6 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Wiki/n_gram_tracing/ngram_tracing_results_jaccard_06.xlsx
# Skipping n = 7 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Wiki/n_gram_tracing/ngram_tracing_results_jaccard_07.xlsx
# Skipping n = 8 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Wiki/n_gram_tracing/ngram_tracing_results_jaccard_08.xlsx
# Skipping n = 9 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Wiki/n_gram_tracing/ngram_tracing_results_jaccard_09.xlsx
# Skipping n = 10 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Wiki/n_gram_tracing/ngram_tracing_results_jaccard_10.xlsx
# [1] "Working on Corpus: Enron with Metric: simpson"
# Skipping n = 2 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Enron/n_gram_tracing/ngram_tracing_results_simpson_02.xlsx
# Skipping n = 3 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Enron/n_gram_tracing/ngram_tracing_results_simpson_03.xlsx
# Skipping n = 4 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Enron/n_gram_tracing/ngram_tracing_results_simpson_04.xlsx
# Skipping n = 5 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Enron/n_gram_tracing/ngram_tracing_results_simpson_05.xlsx
# Skipping n = 6 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Enron/n_gram_tracing/ngram_tracing_results_simpson_06.xlsx
# Skipping n = 7 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Enron/n_gram_tracing/ngram_tracing_results_simpson_07.xlsx
# Skipping n = 8 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Enron/n_gram_tracing/ngram_tracing_results_simpson_08.xlsx
# Skipping n = 9 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Enron/n_gram_tracing/ngram_tracing_results_simpson_09.xlsx
# Skipping n = 10 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Enron/n_gram_tracing/ngram_tracing_results_simpson_10.xlsx
# [1] "Working on Corpus: Enron with Metric: jaccard"
# Skipping n = 2 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Enron/n_gram_tracing/ngram_tracing_results_jaccard_02.xlsx
# Skipping n = 3 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Enron/n_gram_tracing/ngram_tracing_results_jaccard_03.xlsx
# Skipping n = 4 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Enron/n_gram_tracing/ngram_tracing_results_jaccard_04.xlsx
# Skipping n = 5 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Enron/n_gram_tracing/ngram_tracing_results_jaccard_05.xlsx
# Skipping n = 6 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Enron/n_gram_tracing/ngram_tracing_results_jaccard_06.xlsx
# Skipping n = 7 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Enron/n_gram_tracing/ngram_tracing_results_jaccard_07.xlsx
# Skipping n = 8 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Enron/n_gram_tracing/ngram_tracing_results_jaccard_08.xlsx
# Skipping n = 9 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Enron/n_gram_tracing/ngram_tracing_results_jaccard_09.xlsx
# Skipping n = 10 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Enron/n_gram_tracing/ngram_tracing_results_jaccard_10.xlsx
# [1] "Working on Corpus: Perverted Justice with Metric: simpson"
# Skipping n = 2 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Perverted Justice/n_gram_tracing/ngram_tracing_results_simpson_02.xlsx
# Skipping n = 3 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Perverted Justice/n_gram_tracing/ngram_tracing_results_simpson_03.xlsx
# Skipping n = 4 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Perverted Justice/n_gram_tracing/ngram_tracing_results_simpson_04.xlsx
# Skipping n = 5 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Perverted Justice/n_gram_tracing/ngram_tracing_results_simpson_05.xlsx
# Skipping n = 6 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Perverted Justice/n_gram_tracing/ngram_tracing_results_simpson_06.xlsx
# Skipping n = 7 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Perverted Justice/n_gram_tracing/ngram_tracing_results_simpson_07.xlsx
# Skipping n = 8 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Perverted Justice/n_gram_tracing/ngram_tracing_results_simpson_08.xlsx
# Skipping n = 9 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Perverted Justice/n_gram_tracing/ngram_tracing_results_simpson_09.xlsx
# Skipping n = 10 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Perverted Justice/n_gram_tracing/ngram_tracing_results_simpson_10.xlsx
# [1] "Working on Corpus: Perverted Justice with Metric: jaccard"
# Skipping n = 2 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Perverted Justice/n_gram_tracing/ngram_tracing_results_jaccard_02.xlsx
# Skipping n = 3 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Perverted Justice/n_gram_tracing/ngram_tracing_results_jaccard_03.xlsx
# Skipping n = 4 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Perverted Justice/n_gram_tracing/ngram_tracing_results_jaccard_04.xlsx
# Skipping n = 5 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Perverted Justice/n_gram_tracing/ngram_tracing_results_jaccard_05.xlsx
# Skipping n = 6 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Perverted Justice/n_gram_tracing/ngram_tracing_results_jaccard_06.xlsx
# Skipping n = 7 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Perverted Justice/n_gram_tracing/ngram_tracing_results_jaccard_07.xlsx
# Skipping n = 8 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Perverted Justice/n_gram_tracing/ngram_tracing_results_jaccard_08.xlsx
# Skipping n = 9 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Perverted Justice/n_gram_tracing/ngram_tracing_results_jaccard_09.xlsx
# Skipping n = 10 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Perverted Justice/n_gram_tracing/ngram_tracing_results_jaccard_10.xlsx
# [1] "Working on Corpus: StackExchange with Metric: simpson"
# Skipping n = 2 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/StackExchange/n_gram_tracing/ngram_tracing_results_simpson_02.xlsx
# Skipping n = 3 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/StackExchange/n_gram_tracing/ngram_tracing_results_simpson_03.xlsx
# Skipping n = 4 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/StackExchange/n_gram_tracing/ngram_tracing_results_simpson_04.xlsx
# Skipping n = 5 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/StackExchange/n_gram_tracing/ngram_tracing_results_simpson_05.xlsx
# Skipping n = 6 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/StackExchange/n_gram_tracing/ngram_tracing_results_simpson_06.xlsx
# Skipping n = 7 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/StackExchange/n_gram_tracing/ngram_tracing_results_simpson_07.xlsx
# Skipping n = 8 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/StackExchange/n_gram_tracing/ngram_tracing_results_simpson_08.xlsx
# Skipping n = 9 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/StackExchange/n_gram_tracing/ngram_tracing_results_simpson_09.xlsx
# Skipping n = 10 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/StackExchange/n_gram_tracing/ngram_tracing_results_simpson_10.xlsx
# [1] "Working on Corpus: StackExchange with Metric: jaccard"
# Skipping n = 2 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/StackExchange/n_gram_tracing/ngram_tracing_results_jaccard_02.xlsx
# Skipping n = 3 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/StackExchange/n_gram_tracing/ngram_tracing_results_jaccard_03.xlsx
# Skipping n = 4 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/StackExchange/n_gram_tracing/ngram_tracing_results_jaccard_04.xlsx
# Skipping n = 5 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/StackExchange/n_gram_tracing/ngram_tracing_results_jaccard_05.xlsx
# Skipping n = 6 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/StackExchange/n_gram_tracing/ngram_tracing_results_jaccard_06.xlsx
# Skipping n = 7 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/StackExchange/n_gram_tracing/ngram_tracing_results_jaccard_07.xlsx
# Skipping n = 8 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/StackExchange/n_gram_tracing/ngram_tracing_results_jaccard_08.xlsx
# Skipping n = 9 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/StackExchange/n_gram_tracing/ngram_tracing_results_jaccard_09.xlsx
# Skipping n = 10 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/StackExchange/n_gram_tracing/ngram_tracing_results_jaccard_10.xlsx
# [1] "Working on Corpus: ACL with Metric: simpson"
# Skipping n = 2 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/ACL/n_gram_tracing/ngram_tracing_results_simpson_02.xlsx
# Skipping n = 3 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/ACL/n_gram_tracing/ngram_tracing_results_simpson_03.xlsx
# Skipping n = 4 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/ACL/n_gram_tracing/ngram_tracing_results_simpson_04.xlsx
# Skipping n = 5 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/ACL/n_gram_tracing/ngram_tracing_results_simpson_05.xlsx
# Skipping n = 6 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/ACL/n_gram_tracing/ngram_tracing_results_simpson_06.xlsx
# Skipping n = 7 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/ACL/n_gram_tracing/ngram_tracing_results_simpson_07.xlsx
# Skipping n = 8 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/ACL/n_gram_tracing/ngram_tracing_results_simpson_08.xlsx
# Skipping n = 9 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/ACL/n_gram_tracing/ngram_tracing_results_simpson_09.xlsx
# Skipping n = 10 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/ACL/n_gram_tracing/ngram_tracing_results_simpson_10.xlsx
# [1] "Working on Corpus: ACL with Metric: jaccard"
# Skipping n = 2 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/ACL/n_gram_tracing/ngram_tracing_results_jaccard_02.xlsx
# Skipping n = 3 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/ACL/n_gram_tracing/ngram_tracing_results_jaccard_03.xlsx
# Skipping n = 4 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/ACL/n_gram_tracing/ngram_tracing_results_jaccard_04.xlsx
# Skipping n = 5 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/ACL/n_gram_tracing/ngram_tracing_results_jaccard_05.xlsx
# Skipping n = 6 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/ACL/n_gram_tracing/ngram_tracing_results_jaccard_06.xlsx
# Skipping n = 7 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/ACL/n_gram_tracing/ngram_tracing_results_jaccard_07.xlsx
# Skipping n = 8 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/ACL/n_gram_tracing/ngram_tracing_results_jaccard_08.xlsx
# Skipping n = 9 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/ACL/n_gram_tracing/ngram_tracing_results_jaccard_09.xlsx
# Skipping n = 10 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/ACL/n_gram_tracing/ngram_tracing_results_jaccard_10.xlsx
# [1] "Working on Corpus: TripAdvisor with Metric: simpson"
# Skipping n = 2 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/TripAdvisor/n_gram_tracing/ngram_tracing_results_simpson_02.xlsx
# Skipping n = 3 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/TripAdvisor/n_gram_tracing/ngram_tracing_results_simpson_03.xlsx
# Skipping n = 4 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/TripAdvisor/n_gram_tracing/ngram_tracing_results_simpson_04.xlsx
# Skipping n = 5 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/TripAdvisor/n_gram_tracing/ngram_tracing_results_simpson_05.xlsx
# Skipping n = 6 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/TripAdvisor/n_gram_tracing/ngram_tracing_results_simpson_06.xlsx
# Skipping n = 7 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/TripAdvisor/n_gram_tracing/ngram_tracing_results_simpson_07.xlsx
# Skipping n = 8 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/TripAdvisor/n_gram_tracing/ngram_tracing_results_simpson_08.xlsx
# Skipping n = 9 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/TripAdvisor/n_gram_tracing/ngram_tracing_results_simpson_09.xlsx
# Skipping n = 10 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/TripAdvisor/n_gram_tracing/ngram_tracing_results_simpson_10.xlsx
# [1] "Working on Corpus: TripAdvisor with Metric: jaccard"
# Skipping n = 2 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/TripAdvisor/n_gram_tracing/ngram_tracing_results_jaccard_02.xlsx
# Skipping n = 3 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/TripAdvisor/n_gram_tracing/ngram_tracing_results_jaccard_03.xlsx
# Skipping n = 4 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/TripAdvisor/n_gram_tracing/ngram_tracing_results_jaccard_04.xlsx
# Skipping n = 5 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/TripAdvisor/n_gram_tracing/ngram_tracing_results_jaccard_05.xlsx
# Skipping n = 6 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/TripAdvisor/n_gram_tracing/ngram_tracing_results_jaccard_06.xlsx
# Skipping n = 7 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/TripAdvisor/n_gram_tracing/ngram_tracing_results_jaccard_07.xlsx
# Skipping n = 8 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/TripAdvisor/n_gram_tracing/ngram_tracing_results_jaccard_08.xlsx
# Skipping n = 9 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/TripAdvisor/n_gram_tracing/ngram_tracing_results_jaccard_09.xlsx
# Skipping n = 10 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/TripAdvisor/n_gram_tracing/ngram_tracing_results_jaccard_10.xlsx
# [1] "Working on Corpus: The Apricity with Metric: simpson"
# Skipping n = 2 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/The Apricity/n_gram_tracing/ngram_tracing_results_simpson_02.xlsx
# Skipping n = 3 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/The Apricity/n_gram_tracing/ngram_tracing_results_simpson_03.xlsx
# Skipping n = 4 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/The Apricity/n_gram_tracing/ngram_tracing_results_simpson_04.xlsx
# Skipping n = 5 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/The Apricity/n_gram_tracing/ngram_tracing_results_simpson_05.xlsx
# Skipping n = 6 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/The Apricity/n_gram_tracing/ngram_tracing_results_simpson_06.xlsx
# Skipping n = 7 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/The Apricity/n_gram_tracing/ngram_tracing_results_simpson_07.xlsx
# Skipping n = 8 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/The Apricity/n_gram_tracing/ngram_tracing_results_simpson_08.xlsx
# Skipping n = 9 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/The Apricity/n_gram_tracing/ngram_tracing_results_simpson_09.xlsx
# Skipping n = 10 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/The Apricity/n_gram_tracing/ngram_tracing_results_simpson_10.xlsx
# [1] "Working on Corpus: The Apricity with Metric: jaccard"
# Skipping n = 2 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/The Apricity/n_gram_tracing/ngram_tracing_results_jaccard_02.xlsx
# Skipping n = 3 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/The Apricity/n_gram_tracing/ngram_tracing_results_jaccard_03.xlsx
# Skipping n = 4 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/The Apricity/n_gram_tracing/ngram_tracing_results_jaccard_04.xlsx
# Skipping n = 5 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/The Apricity/n_gram_tracing/ngram_tracing_results_jaccard_05.xlsx
# Skipping n = 6 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/The Apricity/n_gram_tracing/ngram_tracing_results_jaccard_06.xlsx
# Skipping n = 7 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/The Apricity/n_gram_tracing/ngram_tracing_results_jaccard_07.xlsx
# Skipping n = 8 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/The Apricity/n_gram_tracing/ngram_tracing_results_jaccard_08.xlsx
# Skipping n = 9 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/The Apricity/n_gram_tracing/ngram_tracing_results_jaccard_09.xlsx
# Skipping n = 10 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/The Apricity/n_gram_tracing/ngram_tracing_results_jaccard_10.xlsx
# [1] "Working on Corpus: Koppel's Blogs with Metric: simpson"
# Skipping n = 2 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Koppel's Blogs/n_gram_tracing/ngram_tracing_results_simpson_02.xlsx
# Skipping n = 3 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Koppel's Blogs/n_gram_tracing/ngram_tracing_results_simpson_03.xlsx
# Skipping n = 4 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Koppel's Blogs/n_gram_tracing/ngram_tracing_results_simpson_04.xlsx
# Skipping n = 5 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Koppel's Blogs/n_gram_tracing/ngram_tracing_results_simpson_05.xlsx
# Skipping n = 6 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Koppel's Blogs/n_gram_tracing/ngram_tracing_results_simpson_06.xlsx
# Skipping n = 7 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Koppel's Blogs/n_gram_tracing/ngram_tracing_results_simpson_07.xlsx
# Skipping n = 8 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Koppel's Blogs/n_gram_tracing/ngram_tracing_results_simpson_08.xlsx
# Skipping n = 9 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Koppel's Blogs/n_gram_tracing/ngram_tracing_results_simpson_09.xlsx
# Skipping n = 10 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Koppel's Blogs/n_gram_tracing/ngram_tracing_results_simpson_10.xlsx
# [1] "Working on Corpus: Koppel's Blogs with Metric: jaccard"
# Skipping n = 2 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Koppel's Blogs/n_gram_tracing/ngram_tracing_results_jaccard_02.xlsx
# Skipping n = 3 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Koppel's Blogs/n_gram_tracing/ngram_tracing_results_jaccard_03.xlsx
# Skipping n = 4 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Koppel's Blogs/n_gram_tracing/ngram_tracing_results_jaccard_04.xlsx
# Skipping n = 5 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Koppel's Blogs/n_gram_tracing/ngram_tracing_results_jaccard_05.xlsx
# Skipping n = 6 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Koppel's Blogs/n_gram_tracing/ngram_tracing_results_jaccard_06.xlsx
# Skipping n = 7 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Koppel's Blogs/n_gram_tracing/ngram_tracing_results_jaccard_07.xlsx
# Skipping n = 8 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Koppel's Blogs/n_gram_tracing/ngram_tracing_results_jaccard_08.xlsx
# Skipping n = 9 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Koppel's Blogs/n_gram_tracing/ngram_tracing_results_jaccard_09.xlsx
# Skipping n = 10 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Koppel's Blogs/n_gram_tracing/ngram_tracing_results_jaccard_10.xlsx
# [1] "Working on Corpus: The Telegraph with Metric: simpson"
# Skipping n = 2 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/The Telegraph/n_gram_tracing/ngram_tracing_results_simpson_02.xlsx
# Skipping n = 3 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/The Telegraph/n_gram_tracing/ngram_tracing_results_simpson_03.xlsx
# Skipping n = 4 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/The Telegraph/n_gram_tracing/ngram_tracing_results_simpson_04.xlsx
# Skipping n = 5 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/The Telegraph/n_gram_tracing/ngram_tracing_results_simpson_05.xlsx
# Skipping n = 6 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/The Telegraph/n_gram_tracing/ngram_tracing_results_simpson_06.xlsx
# Skipping n = 7 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/The Telegraph/n_gram_tracing/ngram_tracing_results_simpson_07.xlsx
# Skipping n = 8 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/The Telegraph/n_gram_tracing/ngram_tracing_results_simpson_08.xlsx
# Skipping n = 9 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/The Telegraph/n_gram_tracing/ngram_tracing_results_simpson_09.xlsx
# Skipping n = 10 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/The Telegraph/n_gram_tracing/ngram_tracing_results_simpson_10.xlsx
# [1] "Working on Corpus: The Telegraph with Metric: jaccard"
# Skipping n = 2 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/The Telegraph/n_gram_tracing/ngram_tracing_results_jaccard_02.xlsx
# Skipping n = 3 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/The Telegraph/n_gram_tracing/ngram_tracing_results_jaccard_03.xlsx
# Skipping n = 4 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/The Telegraph/n_gram_tracing/ngram_tracing_results_jaccard_04.xlsx
# Skipping n = 5 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/The Telegraph/n_gram_tracing/ngram_tracing_results_jaccard_05.xlsx
# Skipping n = 6 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/The Telegraph/n_gram_tracing/ngram_tracing_results_jaccard_06.xlsx
# Skipping n = 7 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/The Telegraph/n_gram_tracing/ngram_tracing_results_jaccard_07.xlsx
# Skipping n = 8 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/The Telegraph/n_gram_tracing/ngram_tracing_results_jaccard_08.xlsx
# Skipping n = 9 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/The Telegraph/n_gram_tracing/ngram_tracing_results_jaccard_09.xlsx
# Skipping n = 10 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/The Telegraph/n_gram_tracing/ngram_tracing_results_jaccard_10.xlsx
# [1] "Working on Corpus: Reddit with Metric: simpson"
# Skipping n = 2 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Reddit/n_gram_tracing/ngram_tracing_results_simpson_02.xlsx
# Skipping n = 3 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Reddit/n_gram_tracing/ngram_tracing_results_simpson_03.xlsx
# Skipping n = 4 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Reddit/n_gram_tracing/ngram_tracing_results_simpson_04.xlsx
# Skipping n = 5 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Reddit/n_gram_tracing/ngram_tracing_results_simpson_05.xlsx
# Skipping n = 6 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Reddit/n_gram_tracing/ngram_tracing_results_simpson_06.xlsx
# Skipping n = 7 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Reddit/n_gram_tracing/ngram_tracing_results_simpson_07.xlsx
# Skipping n = 8 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Reddit/n_gram_tracing/ngram_tracing_results_simpson_08.xlsx
# Skipping n = 9 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Reddit/n_gram_tracing/ngram_tracing_results_simpson_09.xlsx
# Skipping n = 10 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Reddit/n_gram_tracing/ngram_tracing_results_simpson_10.xlsx
# [1] "Working on Corpus: Reddit with Metric: jaccard"
# Skipping n = 2 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Reddit/n_gram_tracing/ngram_tracing_results_jaccard_02.xlsx
# Skipping n = 3 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Reddit/n_gram_tracing/ngram_tracing_results_jaccard_03.xlsx
# Skipping n = 4 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Reddit/n_gram_tracing/ngram_tracing_results_jaccard_04.xlsx
# Skipping n = 5 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Reddit/n_gram_tracing/ngram_tracing_results_jaccard_05.xlsx
# Skipping n = 6 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Reddit/n_gram_tracing/ngram_tracing_results_jaccard_06.xlsx
# Skipping n = 7 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Reddit/n_gram_tracing/ngram_tracing_results_jaccard_07.xlsx
# Skipping n = 8 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Reddit/n_gram_tracing/ngram_tracing_results_jaccard_08.xlsx
# Skipping n = 9 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Reddit/n_gram_tracing/ngram_tracing_results_jaccard_09.xlsx
# Skipping n = 10 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/test/Reddit/n_gram_tracing/ngram_tracing_results_jaccard_10.xlsx
# [1] "Working on Corpus: Wiki with Metric: simpson"
# Skipping n = 2 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Wiki/n_gram_tracing/ngram_tracing_results_simpson_02.xlsx
# Skipping n = 3 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Wiki/n_gram_tracing/ngram_tracing_results_simpson_03.xlsx
# Skipping n = 4 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Wiki/n_gram_tracing/ngram_tracing_results_simpson_04.xlsx
# Skipping n = 5 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Wiki/n_gram_tracing/ngram_tracing_results_simpson_05.xlsx
# Skipping n = 6 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Wiki/n_gram_tracing/ngram_tracing_results_simpson_06.xlsx
# Skipping n = 7 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Wiki/n_gram_tracing/ngram_tracing_results_simpson_07.xlsx
# Skipping n = 8 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Wiki/n_gram_tracing/ngram_tracing_results_simpson_08.xlsx
# Skipping n = 9 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Wiki/n_gram_tracing/ngram_tracing_results_simpson_09.xlsx
# Skipping n = 10 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Wiki/n_gram_tracing/ngram_tracing_results_simpson_10.xlsx
# [1] "Working on Corpus: Wiki with Metric: jaccard"
# Skipping n = 2 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Wiki/n_gram_tracing/ngram_tracing_results_jaccard_02.xlsx
# Skipping n = 3 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Wiki/n_gram_tracing/ngram_tracing_results_jaccard_03.xlsx
# Skipping n = 4 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Wiki/n_gram_tracing/ngram_tracing_results_jaccard_04.xlsx
# Skipping n = 5 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Wiki/n_gram_tracing/ngram_tracing_results_jaccard_05.xlsx
# Skipping n = 6 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Wiki/n_gram_tracing/ngram_tracing_results_jaccard_06.xlsx
# Skipping n = 7 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Wiki/n_gram_tracing/ngram_tracing_results_jaccard_07.xlsx
# Skipping n = 8 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Wiki/n_gram_tracing/ngram_tracing_results_jaccard_08.xlsx
# Skipping n = 9 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Wiki/n_gram_tracing/ngram_tracing_results_jaccard_09.xlsx
# Skipping n = 10 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Wiki/n_gram_tracing/ngram_tracing_results_jaccard_10.xlsx
# [1] "Working on Corpus: Enron with Metric: simpson"
# Skipping n = 2 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Enron/n_gram_tracing/ngram_tracing_results_simpson_02.xlsx
# Skipping n = 3 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Enron/n_gram_tracing/ngram_tracing_results_simpson_03.xlsx
# Skipping n = 4 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Enron/n_gram_tracing/ngram_tracing_results_simpson_04.xlsx
# Skipping n = 5 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Enron/n_gram_tracing/ngram_tracing_results_simpson_05.xlsx
# Skipping n = 6 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Enron/n_gram_tracing/ngram_tracing_results_simpson_06.xlsx
# Skipping n = 7 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Enron/n_gram_tracing/ngram_tracing_results_simpson_07.xlsx
# Skipping n = 8 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Enron/n_gram_tracing/ngram_tracing_results_simpson_08.xlsx
# Skipping n = 9 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Enron/n_gram_tracing/ngram_tracing_results_simpson_09.xlsx
# Skipping n = 10 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Enron/n_gram_tracing/ngram_tracing_results_simpson_10.xlsx
# [1] "Working on Corpus: Enron with Metric: jaccard"
# Skipping n = 2 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Enron/n_gram_tracing/ngram_tracing_results_jaccard_02.xlsx
# Skipping n = 3 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Enron/n_gram_tracing/ngram_tracing_results_jaccard_03.xlsx
# Skipping n = 4 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Enron/n_gram_tracing/ngram_tracing_results_jaccard_04.xlsx
# Skipping n = 5 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Enron/n_gram_tracing/ngram_tracing_results_jaccard_05.xlsx
# Skipping n = 6 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Enron/n_gram_tracing/ngram_tracing_results_jaccard_06.xlsx
# Skipping n = 7 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Enron/n_gram_tracing/ngram_tracing_results_jaccard_07.xlsx
# Skipping n = 8 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Enron/n_gram_tracing/ngram_tracing_results_jaccard_08.xlsx
# Skipping n = 9 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Enron/n_gram_tracing/ngram_tracing_results_jaccard_09.xlsx
# Skipping n = 10 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Enron/n_gram_tracing/ngram_tracing_results_jaccard_10.xlsx
# [1] "Working on Corpus: Perverted Justice with Metric: simpson"
# Skipping n = 2 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Perverted Justice/n_gram_tracing/ngram_tracing_results_simpson_02.xlsx
# Skipping n = 3 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Perverted Justice/n_gram_tracing/ngram_tracing_results_simpson_03.xlsx
# Skipping n = 4 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Perverted Justice/n_gram_tracing/ngram_tracing_results_simpson_04.xlsx
# Skipping n = 5 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Perverted Justice/n_gram_tracing/ngram_tracing_results_simpson_05.xlsx
# Skipping n = 6 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Perverted Justice/n_gram_tracing/ngram_tracing_results_simpson_06.xlsx
# Skipping n = 7 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Perverted Justice/n_gram_tracing/ngram_tracing_results_simpson_07.xlsx
# Skipping n = 8 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Perverted Justice/n_gram_tracing/ngram_tracing_results_simpson_08.xlsx
# Skipping n = 9 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Perverted Justice/n_gram_tracing/ngram_tracing_results_simpson_09.xlsx
# Skipping n = 10 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Perverted Justice/n_gram_tracing/ngram_tracing_results_simpson_10.xlsx
# [1] "Working on Corpus: Perverted Justice with Metric: jaccard"
# Skipping n = 2 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Perverted Justice/n_gram_tracing/ngram_tracing_results_jaccard_02.xlsx
# Skipping n = 3 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Perverted Justice/n_gram_tracing/ngram_tracing_results_jaccard_03.xlsx
# Skipping n = 4 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Perverted Justice/n_gram_tracing/ngram_tracing_results_jaccard_04.xlsx
# Skipping n = 5 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Perverted Justice/n_gram_tracing/ngram_tracing_results_jaccard_05.xlsx
# Skipping n = 6 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Perverted Justice/n_gram_tracing/ngram_tracing_results_jaccard_06.xlsx
# Skipping n = 7 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Perverted Justice/n_gram_tracing/ngram_tracing_results_jaccard_07.xlsx
# Skipping n = 8 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Perverted Justice/n_gram_tracing/ngram_tracing_results_jaccard_08.xlsx
# Skipping n = 9 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Perverted Justice/n_gram_tracing/ngram_tracing_results_jaccard_09.xlsx
# Skipping n = 10 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Perverted Justice/n_gram_tracing/ngram_tracing_results_jaccard_10.xlsx
# [1] "Working on Corpus: StackExchange with Metric: simpson"
# Skipping n = 2 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/StackExchange/n_gram_tracing/ngram_tracing_results_simpson_02.xlsx
# Skipping n = 3 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/StackExchange/n_gram_tracing/ngram_tracing_results_simpson_03.xlsx
# Skipping n = 4 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/StackExchange/n_gram_tracing/ngram_tracing_results_simpson_04.xlsx
# Skipping n = 5 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/StackExchange/n_gram_tracing/ngram_tracing_results_simpson_05.xlsx
# Skipping n = 6 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/StackExchange/n_gram_tracing/ngram_tracing_results_simpson_06.xlsx
# Skipping n = 7 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/StackExchange/n_gram_tracing/ngram_tracing_results_simpson_07.xlsx
# Skipping n = 8 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/StackExchange/n_gram_tracing/ngram_tracing_results_simpson_08.xlsx
# Skipping n = 9 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/StackExchange/n_gram_tracing/ngram_tracing_results_simpson_09.xlsx
# Skipping n = 10 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/StackExchange/n_gram_tracing/ngram_tracing_results_simpson_10.xlsx
# [1] "Working on Corpus: StackExchange with Metric: jaccard"
# Skipping n = 2 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/StackExchange/n_gram_tracing/ngram_tracing_results_jaccard_02.xlsx
# Skipping n = 3 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/StackExchange/n_gram_tracing/ngram_tracing_results_jaccard_03.xlsx
# Skipping n = 4 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/StackExchange/n_gram_tracing/ngram_tracing_results_jaccard_04.xlsx
# Skipping n = 5 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/StackExchange/n_gram_tracing/ngram_tracing_results_jaccard_05.xlsx
# Skipping n = 6 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/StackExchange/n_gram_tracing/ngram_tracing_results_jaccard_06.xlsx
# Skipping n = 7 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/StackExchange/n_gram_tracing/ngram_tracing_results_jaccard_07.xlsx
# Skipping n = 8 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/StackExchange/n_gram_tracing/ngram_tracing_results_jaccard_08.xlsx
# Skipping n = 9 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/StackExchange/n_gram_tracing/ngram_tracing_results_jaccard_09.xlsx
# Skipping n = 10 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/StackExchange/n_gram_tracing/ngram_tracing_results_jaccard_10.xlsx
# [1] "Working on Corpus: ACL with Metric: simpson"
# Skipping n = 2 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/ACL/n_gram_tracing/ngram_tracing_results_simpson_02.xlsx
# Skipping n = 3 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/ACL/n_gram_tracing/ngram_tracing_results_simpson_03.xlsx
# Skipping n = 4 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/ACL/n_gram_tracing/ngram_tracing_results_simpson_04.xlsx
# Skipping n = 5 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/ACL/n_gram_tracing/ngram_tracing_results_simpson_05.xlsx
# Skipping n = 6 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/ACL/n_gram_tracing/ngram_tracing_results_simpson_06.xlsx
# Skipping n = 7 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/ACL/n_gram_tracing/ngram_tracing_results_simpson_07.xlsx
# Skipping n = 8 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/ACL/n_gram_tracing/ngram_tracing_results_simpson_08.xlsx
# Skipping n = 9 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/ACL/n_gram_tracing/ngram_tracing_results_simpson_09.xlsx
# Skipping n = 10 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/ACL/n_gram_tracing/ngram_tracing_results_simpson_10.xlsx
# [1] "Working on Corpus: ACL with Metric: jaccard"
# Skipping n = 2 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/ACL/n_gram_tracing/ngram_tracing_results_jaccard_02.xlsx
# Skipping n = 3 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/ACL/n_gram_tracing/ngram_tracing_results_jaccard_03.xlsx
# Skipping n = 4 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/ACL/n_gram_tracing/ngram_tracing_results_jaccard_04.xlsx
# Skipping n = 5 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/ACL/n_gram_tracing/ngram_tracing_results_jaccard_05.xlsx
# Skipping n = 6 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/ACL/n_gram_tracing/ngram_tracing_results_jaccard_06.xlsx
# Skipping n = 7 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/ACL/n_gram_tracing/ngram_tracing_results_jaccard_07.xlsx
# Skipping n = 8 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/ACL/n_gram_tracing/ngram_tracing_results_jaccard_08.xlsx
# Skipping n = 9 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/ACL/n_gram_tracing/ngram_tracing_results_jaccard_09.xlsx
# Skipping n = 10 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/ACL/n_gram_tracing/ngram_tracing_results_jaccard_10.xlsx
# [1] "Working on Corpus: TripAdvisor with Metric: simpson"
# Skipping n = 2 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/TripAdvisor/n_gram_tracing/ngram_tracing_results_simpson_02.xlsx
# Skipping n = 3 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/TripAdvisor/n_gram_tracing/ngram_tracing_results_simpson_03.xlsx
# Skipping n = 4 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/TripAdvisor/n_gram_tracing/ngram_tracing_results_simpson_04.xlsx
# Skipping n = 5 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/TripAdvisor/n_gram_tracing/ngram_tracing_results_simpson_05.xlsx
# Skipping n = 6 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/TripAdvisor/n_gram_tracing/ngram_tracing_results_simpson_06.xlsx
# Skipping n = 7 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/TripAdvisor/n_gram_tracing/ngram_tracing_results_simpson_07.xlsx
# Skipping n = 8 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/TripAdvisor/n_gram_tracing/ngram_tracing_results_simpson_08.xlsx
# Skipping n = 9 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/TripAdvisor/n_gram_tracing/ngram_tracing_results_simpson_09.xlsx
# Skipping n = 10 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/TripAdvisor/n_gram_tracing/ngram_tracing_results_simpson_10.xlsx
# [1] "Working on Corpus: TripAdvisor with Metric: jaccard"
# Skipping n = 2 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/TripAdvisor/n_gram_tracing/ngram_tracing_results_jaccard_02.xlsx
# Skipping n = 3 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/TripAdvisor/n_gram_tracing/ngram_tracing_results_jaccard_03.xlsx
# Skipping n = 4 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/TripAdvisor/n_gram_tracing/ngram_tracing_results_jaccard_04.xlsx
# Skipping n = 5 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/TripAdvisor/n_gram_tracing/ngram_tracing_results_jaccard_05.xlsx
# Skipping n = 6 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/TripAdvisor/n_gram_tracing/ngram_tracing_results_jaccard_06.xlsx
# Skipping n = 7 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/TripAdvisor/n_gram_tracing/ngram_tracing_results_jaccard_07.xlsx
# Skipping n = 8 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/TripAdvisor/n_gram_tracing/ngram_tracing_results_jaccard_08.xlsx
# Skipping n = 9 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/TripAdvisor/n_gram_tracing/ngram_tracing_results_jaccard_09.xlsx
# Skipping n = 10 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/TripAdvisor/n_gram_tracing/ngram_tracing_results_jaccard_10.xlsx
# [1] "Working on Corpus: The Apricity with Metric: simpson"
# Skipping n = 2 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/The Apricity/n_gram_tracing/ngram_tracing_results_simpson_02.xlsx
# Skipping n = 3 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/The Apricity/n_gram_tracing/ngram_tracing_results_simpson_03.xlsx
# Skipping n = 4 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/The Apricity/n_gram_tracing/ngram_tracing_results_simpson_04.xlsx
# Skipping n = 5 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/The Apricity/n_gram_tracing/ngram_tracing_results_simpson_05.xlsx
# Skipping n = 6 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/The Apricity/n_gram_tracing/ngram_tracing_results_simpson_06.xlsx
# Skipping n = 7 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/The Apricity/n_gram_tracing/ngram_tracing_results_simpson_07.xlsx
# Skipping n = 8 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/The Apricity/n_gram_tracing/ngram_tracing_results_simpson_08.xlsx
# Skipping n = 9 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/The Apricity/n_gram_tracing/ngram_tracing_results_simpson_09.xlsx
# Skipping n = 10 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/The Apricity/n_gram_tracing/ngram_tracing_results_simpson_10.xlsx
# [1] "Working on Corpus: The Apricity with Metric: jaccard"
# Skipping n = 2 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/The Apricity/n_gram_tracing/ngram_tracing_results_jaccard_02.xlsx
# Skipping n = 3 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/The Apricity/n_gram_tracing/ngram_tracing_results_jaccard_03.xlsx
# Skipping n = 4 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/The Apricity/n_gram_tracing/ngram_tracing_results_jaccard_04.xlsx
# Skipping n = 5 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/The Apricity/n_gram_tracing/ngram_tracing_results_jaccard_05.xlsx
# Skipping n = 6 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/The Apricity/n_gram_tracing/ngram_tracing_results_jaccard_06.xlsx
# Skipping n = 7 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/The Apricity/n_gram_tracing/ngram_tracing_results_jaccard_07.xlsx
# Skipping n = 8 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/The Apricity/n_gram_tracing/ngram_tracing_results_jaccard_08.xlsx
# Skipping n = 9 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/The Apricity/n_gram_tracing/ngram_tracing_results_jaccard_09.xlsx
# Skipping n = 10 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/The Apricity/n_gram_tracing/ngram_tracing_results_jaccard_10.xlsx
# [1] "Working on Corpus: Koppel's Blogs with Metric: simpson"
# Skipping n = 2 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Koppel's Blogs/n_gram_tracing/ngram_tracing_results_simpson_02.xlsx
# Skipping n = 3 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Koppel's Blogs/n_gram_tracing/ngram_tracing_results_simpson_03.xlsx
# Skipping n = 4 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Koppel's Blogs/n_gram_tracing/ngram_tracing_results_simpson_04.xlsx
# Skipping n = 5 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Koppel's Blogs/n_gram_tracing/ngram_tracing_results_simpson_05.xlsx
# Skipping n = 6 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Koppel's Blogs/n_gram_tracing/ngram_tracing_results_simpson_06.xlsx
# Skipping n = 7 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Koppel's Blogs/n_gram_tracing/ngram_tracing_results_simpson_07.xlsx
# Skipping n = 8 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Koppel's Blogs/n_gram_tracing/ngram_tracing_results_simpson_08.xlsx
# Skipping n = 9 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Koppel's Blogs/n_gram_tracing/ngram_tracing_results_simpson_09.xlsx
# Skipping n = 10 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Koppel's Blogs/n_gram_tracing/ngram_tracing_results_simpson_10.xlsx
# [1] "Working on Corpus: Koppel's Blogs with Metric: jaccard"
# Skipping n = 2 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Koppel's Blogs/n_gram_tracing/ngram_tracing_results_jaccard_02.xlsx
# Skipping n = 3 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Koppel's Blogs/n_gram_tracing/ngram_tracing_results_jaccard_03.xlsx
# Skipping n = 4 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Koppel's Blogs/n_gram_tracing/ngram_tracing_results_jaccard_04.xlsx
# Skipping n = 5 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Koppel's Blogs/n_gram_tracing/ngram_tracing_results_jaccard_05.xlsx
# Skipping n = 6 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Koppel's Blogs/n_gram_tracing/ngram_tracing_results_jaccard_06.xlsx
# Skipping n = 7 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Koppel's Blogs/n_gram_tracing/ngram_tracing_results_jaccard_07.xlsx
# Skipping n = 8 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Koppel's Blogs/n_gram_tracing/ngram_tracing_results_jaccard_08.xlsx
# Skipping n = 9 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Koppel's Blogs/n_gram_tracing/ngram_tracing_results_jaccard_09.xlsx
# Skipping n = 10 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Koppel's Blogs/n_gram_tracing/ngram_tracing_results_jaccard_10.xlsx
# [1] "Working on Corpus: The Telegraph with Metric: simpson"
# Skipping n = 2 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/The Telegraph/n_gram_tracing/ngram_tracing_results_simpson_02.xlsx
# Skipping n = 3 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/The Telegraph/n_gram_tracing/ngram_tracing_results_simpson_03.xlsx
# Skipping n = 4 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/The Telegraph/n_gram_tracing/ngram_tracing_results_simpson_04.xlsx
# Skipping n = 5 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/The Telegraph/n_gram_tracing/ngram_tracing_results_simpson_05.xlsx
# Skipping n = 6 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/The Telegraph/n_gram_tracing/ngram_tracing_results_simpson_06.xlsx
# Skipping n = 7 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/The Telegraph/n_gram_tracing/ngram_tracing_results_simpson_07.xlsx
# Skipping n = 8 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/The Telegraph/n_gram_tracing/ngram_tracing_results_simpson_08.xlsx
# Skipping n = 9 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/The Telegraph/n_gram_tracing/ngram_tracing_results_simpson_09.xlsx
# Skipping n = 10 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/The Telegraph/n_gram_tracing/ngram_tracing_results_simpson_10.xlsx
# [1] "Working on Corpus: The Telegraph with Metric: jaccard"
# Skipping n = 2 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/The Telegraph/n_gram_tracing/ngram_tracing_results_jaccard_02.xlsx
# Skipping n = 3 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/The Telegraph/n_gram_tracing/ngram_tracing_results_jaccard_03.xlsx
# Skipping n = 4 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/The Telegraph/n_gram_tracing/ngram_tracing_results_jaccard_04.xlsx
# Skipping n = 5 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/The Telegraph/n_gram_tracing/ngram_tracing_results_jaccard_05.xlsx
# Skipping n = 6 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/The Telegraph/n_gram_tracing/ngram_tracing_results_jaccard_06.xlsx
# Skipping n = 7 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/The Telegraph/n_gram_tracing/ngram_tracing_results_jaccard_07.xlsx
# Skipping n = 8 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/The Telegraph/n_gram_tracing/ngram_tracing_results_jaccard_08.xlsx
# Skipping n = 9 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/The Telegraph/n_gram_tracing/ngram_tracing_results_jaccard_09.xlsx
# Skipping n = 10 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/The Telegraph/n_gram_tracing/ngram_tracing_results_jaccard_10.xlsx
# [1] "Working on Corpus: Reddit with Metric: simpson"
# Skipping n = 2 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Reddit/n_gram_tracing/ngram_tracing_results_simpson_02.xlsx
# Skipping n = 3 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Reddit/n_gram_tracing/ngram_tracing_results_simpson_03.xlsx
# Skipping n = 4 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Reddit/n_gram_tracing/ngram_tracing_results_simpson_04.xlsx
# Skipping n = 5 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Reddit/n_gram_tracing/ngram_tracing_results_simpson_05.xlsx
# Skipping n = 6 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Reddit/n_gram_tracing/ngram_tracing_results_simpson_06.xlsx
# Skipping n = 7 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Reddit/n_gram_tracing/ngram_tracing_results_simpson_07.xlsx
# Skipping n = 8 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Reddit/n_gram_tracing/ngram_tracing_results_simpson_08.xlsx
# Skipping n = 9 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Reddit/n_gram_tracing/ngram_tracing_results_simpson_09.xlsx
# Skipping n = 10 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Reddit/n_gram_tracing/ngram_tracing_results_simpson_10.xlsx
# [1] "Working on Corpus: Reddit with Metric: jaccard"
# Skipping n = 2 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Reddit/n_gram_tracing/ngram_tracing_results_jaccard_02.xlsx
# Skipping n = 3 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Reddit/n_gram_tracing/ngram_tracing_results_jaccard_03.xlsx
# Skipping n = 4 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Reddit/n_gram_tracing/ngram_tracing_results_jaccard_04.xlsx
# Skipping n = 5 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Reddit/n_gram_tracing/ngram_tracing_results_jaccard_05.xlsx
# Skipping n = 6 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Reddit/n_gram_tracing/ngram_tracing_results_jaccard_06.xlsx
# Skipping n = 7 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Reddit/n_gram_tracing/ngram_tracing_results_jaccard_07.xlsx
# Skipping n = 8 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Reddit/n_gram_tracing/ngram_tracing_results_jaccard_08.xlsx
# Skipping n = 9 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Reddit/n_gram_tracing/ngram_tracing_results_jaccard_09.xlsx
# Skipping n = 10 (exists): /Volumes/BCross/av_datasets_experiments/Baseline Results/training/Reddit/n_gram_tracing/ngram_tracing_results_jaccard_10.xlsx

# %% [markdown]
# ## Combine Results

# %%
overall_list <- list()

for (d_type in data_types) {
  
  d_type_list <- list()
  
  d_type_dir <- file.path(base_save_loc, d_type)
  dir.create(d_type_dir, recursive = TRUE, showWarnings = FALSE)
  d_type_save_loc <- file.path(d_type_dir, "n_gram_tracing_results.rds")
  
  for (c_ in corpora) {
    
    corpus_list <- list()
    
    read_dir <- file.path(base_save_loc, d_type, c_, "n_gram_tracing")
    
    if (!dir.exists(read_dir)) {
      message("Skipping (missing dir): ", read_dir)
      next
    }
    
    # Read Excel files, save combined outputs as RDS
    xlsx_files <- list.files(
      path = read_dir,
      pattern = "\\.xlsx$",
      full.names = TRUE,
      ignore.case = TRUE
    )
    
    if (length(xlsx_files) == 0) {
      message("No .xlsx files found for data type/corpus: ", d_type, " / ", c_)
      next
    }
    
    for (filename in xlsx_files) {
      
      if (!file.exists(filename)) {
        message("Skipping (missing file): ", filename)
        next
      }
      
      # If you need a specific sheet, add: sheet = "sheet_name"
      data <- readxl::read_xlsx(filename)
      
      data <- data |>
        mutate(
          data_type = d_type,
          corpus = c_
        ) |>
        relocate(data_type, corpus)
      
      corpus_list[[length(corpus_list) + 1]] <- data
    }
    
    if (length(corpus_list) == 0) {
      message("No readable files for data type/corpus: ", d_type, " / ", c_)
      next
    }
    
    # ---- Corpus-level combined file (saved as .rds) ----
    corpus_combined <- bind_rows(corpus_list)
    
    corpus_dir <- file.path(base_save_loc, d_type, c_)
    dir.create(corpus_dir, recursive = TRUE, showWarnings = FALSE)
    corpus_save_loc <- file.path(corpus_dir, "n_gram_tracing_results.rds")
    
    saveRDS(corpus_combined, corpus_save_loc)
    
    # Add corpus-combined to data-type list
    d_type_list[[length(d_type_list) + 1]] <- corpus_combined
  }
  
  if (length(d_type_list) == 0) {
    message("No files found for data type: ", d_type)
    next
  }
  
  # ---- Data-type-level combined file (saved as .rds) ----
  d_type_combined <- bind_rows(d_type_list)
  saveRDS(d_type_combined, d_type_save_loc)
  
  # Add data-type combined to overall list
  overall_list[[length(overall_list) + 1]] <- d_type_combined
}

# ---- Overall combined file (saved as .rds) ----
if (length(overall_list) > 0) {
  overall_combined <- bind_rows(overall_list)
  overall_save_loc <- file.path(base_save_loc, "n_gram_tracing_results.rds")
  saveRDS(overall_combined, overall_save_loc)
} else {
  message("No files found across any data types.")
}
