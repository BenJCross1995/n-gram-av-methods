# %% [markdown]
# # Use Idiolect Package to Score Data

# %%
suppressWarnings(
  suppressPackageStartupMessages(
    {
      library(readxl)
      library(writexl)
      library(dplyr)
      library(purrr)
      library(tibble)
      library(devtools)
    }
  )
)

# Installs from the local folder (your modified clone)
# if (requireNamespace("idiolect", quietly = TRUE)) {
#   message("Removing Installed Version of Idiolect")
#   invisible(capture.output(remove.packages("idiolect")))
# }

message("Installing CRAN Version of Idiolect")
devtools::install("/Users/user/Documents/GitHub/idiolect", upgrade = "never")

library(idiolect)
# Out:
# Installing CRAN Version of Idiolect
# ── R CMD build ─────────────────────────────────────────────────────────────────
# ✔  checking for file ‘/Users/user/Documents/GitHub/idiolect/DESCRIPTION’ ...
# ─  preparing ‘idiolect’: (361ms)
# ✔  checking DESCRIPTION meta-information ...
# ─  checking for LF line-endings in source and make files and shell scripts
# ─  checking for empty or unneeded directories
# ─  building ‘idiolect_1.1.1.9000.tar.gz’
#
# Running /Library/Frameworks/R.framework/Resources/bin/R CMD INSTALL \
#   /var/folders/xx/hy496x3x5sn4hy9gy1fk19lw0000gp/T//Rtmpg99Z9p/idiolect_1.1.1.9000.tar.gz \
#   --install-tests
# * installing to library ‘/Library/Frameworks/R.framework/Versions/4.2-arm64/Resources/library’
# * installing *source* package ‘idiolect’ ...
# ** using staged installation
# ** R
# ** data
# *** moving datasets to lazyload DB
# ** inst
# ** tests
# ** byte-compile and prepare package for lazy loading
# Warning messages:
# 1: package ‘quanteda’ was built under R version 4.2.3
# 2: In .recacheSubclasses(def@className, def, env) :
#   undefined subclass "ndiMatrix" of class "replValueSp"; definition not updated
# 3: In .recacheSubclasses(def@className, def, env) :
#   undefined subclass "pcorMatrix" of class "replValueSp"; definition not updated
# ** help
# *** installing help indices
# *** copying figures
# ** building package indices
# ** installing vignettes
# ** testing if installed package can be loaded from temporary location
# Warning: package ‘quanteda’ was built under R version 4.2.3
# Warning in .recacheSubclasses(def@className, def, env) :
#   undefined subclass "ndiMatrix" of class "replValueSp"; definition not updated
# Warning in .recacheSubclasses(def@className, def, env) :
#   undefined subclass "pcorMatrix" of class "replValueSp"; definition not updated
# ** testing if installed package can be loaded from final location
# Warning: package ‘quanteda’ was built under R version 4.2.3
# Warning in .recacheSubclasses(def@className, def, env) :
#   undefined subclass "ndiMatrix" of class "replValueSp"; definition not updated
# Warning in .recacheSubclasses(def@className, def, env) :
#   undefined subclass "pcorMatrix" of class "replValueSp"; definition not updated
# ** testing if installed package keeps a record of temporary installation path
# * DONE (idiolect)

# %%
models <- c("gpt2")

corpora <- c(
    "Wiki", "Enron", "Perverted Justice", "StackExchange", "ACL",
    "TripAdvisor", "The Apricity", "Koppel's Blogs", "The Telegraph",
    "Reddit", "Enron Cleaned"
)

data_types <- c("training", "test")

base_loc <- "/Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1"

file_name <- "raw_agg_scores.xlsx"
file_name <- "raw_agg_adjusted_token_size_scores.rds"

save_name <- "idiolect_results.xlsx"

calibrated_save_name <- "idiolect_calibrated_results.xlsx"

combined_save_name <- "raw_idiolect_results_by_context.xlsx"

combined_calibrated_save_name <- "raw_idiolect_calibrated_results_by_context.xlsx"

# %%
get_distinct_problems <- function(df){
  #' Group by specific columns and get a distinct problem list
  
  distinct_problems <- df |>
    dplyr::select(data_type, corpus, scoring_model, max_context_tokens, min_token_size_adjusted) |>
    dplyr::distinct() |>
    dplyr::rename(min_token_size = min_token_size_adjusted)

  return(distinct_problems)
}

# %%
calculate_performance <- function(df, score_col = "unknown_sum_log_probs") {

  problem_df <- get_distinct_problems(df)

  raw_scores <- df |>
    dplyr::rename(score = !!rlang::sym(score_col))

  out_list <- vector("list", nrow(problem_df))

  for (i in seq_len(nrow(problem_df))) {

    row <- problem_df[i, , drop = FALSE]

    data_type          <- row$data_type
    corpus             <- row$corpus
    scoring_model      <- row$scoring_model
    max_context_tokens <- row$max_context_tokens
    min_token_size     <- row$min_token_size

    filtered_df <- raw_scores |>
      dplyr::filter(
        data_type == !!data_type,
        corpus == !!corpus,
        scoring_model == !!scoring_model,
        min_token_size_adjusted == !!min_token_size,
        (is.na(max_context_tokens) & is.na(!!max_context_tokens)) |
          (!is.na(max_context_tokens) & max_context_tokens == !!max_context_tokens)
      )

    perf_eval <- tryCatch(
      {
        out <- performance(filtered_df)
        out$evaluation
      },
      error = function(e) {
        message(sprintf("[%d] -> FAILED (%s)", i, conditionMessage(e)))
        NULL
      }
    )

    if (is.null(perf_eval)) {
      out_list[[i]] <- NULL
      next
    } else {
      perf_eval <- perf_eval |>
        dplyr::filter(!(Cllr == "Inf"))
    }

    out_list[[i]] <- dplyr::bind_cols(
      tibble::as_tibble(row),
      tibble::as_tibble(perf_eval)
    )
  }

  dplyr::bind_rows(out_list)
}

# %%
calculate_calibrated_performance <- function(test_df, training_df, score_col = "unknown_sum_log_probs") {

  # distinct problems should come from TEST only
  problem_df <- get_distinct_problems(test_df)

  test_scores <- test_df |>
    dplyr::rename(score = !!rlang::sym(score_col))

  training_scores <- training_df |>
    dplyr::rename(score = !!rlang::sym(score_col))

  out_list <- vector("list", nrow(problem_df))

  for (i in seq_len(nrow(problem_df))) {

    row <- problem_df[i, , drop = FALSE]

    # NOTE: we intentionally do NOT match on data_type across test/training
    corpus             <- row$corpus
    scoring_model      <- row$scoring_model
    max_context_tokens <- row$max_context_tokens
    min_token_size     <- row$min_token_size

    filtered_test <- test_scores |>
      dplyr::filter(
        corpus == !!corpus,
        scoring_model == !!scoring_model,
        min_token_size_adjusted == !!min_token_size,
        (is.na(max_context_tokens) & is.na(!!max_context_tokens)) |
          (!is.na(max_context_tokens) & max_context_tokens == !!max_context_tokens)
      )

    filtered_training <- training_scores |>
      dplyr::filter(
        corpus == !!corpus,
        scoring_model == !!scoring_model,
        min_token_size_adjusted == !!min_token_size,
        (is.na(max_context_tokens) & is.na(!!max_context_tokens)) |
          (!is.na(max_context_tokens) & max_context_tokens == !!max_context_tokens)
      )

    if (nrow(filtered_training) == 0) {
      message(sprintf("[%d] -> SKIP (no matching training rows)", i))
      out_list[[i]] <- NULL
      next
    }

    perf_eval <- tryCatch(
      {
        out <- performance(filtered_test, training = filtered_training)
        out$evaluation
      },
      error = function(e) {
        message(sprintf("[%d] -> FAILED (%s)", i, conditionMessage(e)))
        NULL
      }
    )

    if (is.null(perf_eval)) {
      out_list[[i]] <- NULL
      next
    } else {
      perf_eval <- perf_eval |>
        dplyr::filter(!(Cllr == "Inf"))
    }

    # keep the TEST metadata row (including data_type="test")
    out_list[[i]] <- dplyr::bind_cols(
      tibble::as_tibble(row),
      tibble::as_tibble(perf_eval)
    )
  }

  dplyr::bind_rows(out_list)
}

# %%
for (data_type in data_types) {
  for (corpus in corpora) {
    for (model_name in models) {

      file_loc <- file.path(base_loc, data_type, corpus, model_name, file_name)
      save_loc <- file.path(base_loc, data_type, corpus, model_name, save_name)

      prefix <- sprintf("%s | %s | %s", data_type, corpus, model_name)

      # skip if already saved
      # if (file.exists(save_loc)) {
      #   message(prefix, " -> SKIP (exists): ", save_loc)
      #   next
      # }

      # skip if input missing
      if (!file.exists(file_loc)) {
        message(prefix, " -> MISSING input: ", file_loc)
        next
      }

      tryCatch(
        {
          message(prefix, " -> reading: ", file_loc)
          df <- readRDS(file_loc)

          message(prefix, " -> calculating performance")
          results <- calculate_performance(df)

          if (is.null(results) || nrow(results) == 0) {
            message(prefix, " -> NO RESULTS (empty), not writing")
            next
          }

          dir.create(dirname(save_loc), recursive = TRUE, showWarnings = FALSE)

          message(prefix, " -> writing: ", save_loc)
          writexl::write_xlsx(results, save_loc)

          message(prefix, " -> OK")
        },
        error = function(e) {
          message(prefix, " -> FAILED: ", conditionMessage(e))
        }
      )

    }
  }
}
# Out:
# training | Wiki | gpt2 -> reading: /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/training/Wiki/gpt2/raw_agg_adjusted_token_size_scores.rds
# training | Wiki | gpt2 -> calculating performance
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
# [7] -> FAILED (Argument mu must be a nonempty numeric vector)
# [8] -> FAILED (Argument mu must be a nonempty numeric vector)
# [9] -> FAILED (Argument mu must be a nonempty numeric vector)
# [10] -> FAILED (Argument mu must be a nonempty numeric vector)
# [11] -> FAILED (Argument mu must be a nonempty numeric vector)
# [12] -> FAILED (Argument mu must be a nonempty numeric vector)
# [13] -> FAILED (Argument mu must be a nonempty numeric vector)
# [14] -> FAILED (Argument mu must be a nonempty numeric vector)
# [15] -> FAILED (Argument mu must be a nonempty numeric vector)
# [16] -> FAILED (Argument mu must be a nonempty numeric vector)
# [17] -> FAILED (Argument mu must be a nonempty numeric vector)
# [18] -> FAILED (Argument mu must be a nonempty numeric vector)
# [19] -> FAILED (Argument mu must be a nonempty numeric vector)
# [20] -> FAILED (Argument mu must be a nonempty numeric vector)
# [21] -> FAILED (Argument mu must be a nonempty numeric vector)
# [22] -> FAILED (Argument mu must be a nonempty numeric vector)
# [23] -> FAILED (Argument mu must be a nonempty numeric vector)
# [24] -> FAILED (Argument mu must be a nonempty numeric vector)
# [25] -> FAILED (Argument mu must be a nonempty numeric vector)
# [26] -> FAILED (Argument mu must be a nonempty numeric vector)
# [27] -> FAILED (Argument mu must be a nonempty numeric vector)
# [28] -> FAILED (must have 'max' > 'min')
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
# [35] -> FAILED (Argument mu must be a nonempty numeric vector)
# [36] -> FAILED (Argument mu must be a nonempty numeric vector)
# [37] -> FAILED (Argument mu must be a nonempty numeric vector)
# [38] -> FAILED (Argument mu must be a nonempty numeric vector)
# [39] -> FAILED (Argument mu must be a nonempty numeric vector)
# [40] -> FAILED (Argument mu must be a nonempty numeric vector)
# [41] -> FAILED (Argument mu must be a nonempty numeric vector)
# [42] -> FAILED (Argument mu must be a nonempty numeric vector)
# [43] -> FAILED (Argument mu must be a nonempty numeric vector)
# [44] -> FAILED (Argument mu must be a nonempty numeric vector)
# [45] -> FAILED (Argument mu must be a nonempty numeric vector)
# [46] -> FAILED (Argument mu must be a nonempty numeric vector)
# [47] -> FAILED (Argument mu must be a nonempty numeric vector)
# [48] -> FAILED (Argument mu must be a nonempty numeric vector)
# [49] -> FAILED (Argument mu must be a nonempty numeric vector)
# [50] -> FAILED (Argument mu must be a nonempty numeric vector)
# [51] -> FAILED (Argument mu must be a nonempty numeric vector)
# [52] -> FAILED (Argument mu must be a nonempty numeric vector)
# [53] -> FAILED (Argument mu must be a nonempty numeric vector)
# [54] -> FAILED (Argument mu must be a nonempty numeric vector)
# [55] -> FAILED (Argument mu must be a nonempty numeric vector)
# [56] -> FAILED (must have 'max' > 'min')
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
# [63] -> FAILED (Argument mu must be a nonempty numeric vector)
# [64] -> FAILED (Argument mu must be a nonempty numeric vector)
# [65] -> FAILED (Argument mu must be a nonempty numeric vector)
# [66] -> FAILED (Argument mu must be a nonempty numeric vector)
# [67] -> FAILED (Argument mu must be a nonempty numeric vector)
# [68] -> FAILED (Argument mu must be a nonempty numeric vector)
# [69] -> FAILED (Argument mu must be a nonempty numeric vector)
# [70] -> FAILED (Argument mu must be a nonempty numeric vector)
# [71] -> FAILED (Argument mu must be a nonempty numeric vector)
# [72] -> FAILED (Argument mu must be a nonempty numeric vector)
# [73] -> FAILED (Argument mu must be a nonempty numeric vector)
# [74] -> FAILED (Argument mu must be a nonempty numeric vector)
# [75] -> FAILED (Argument mu must be a nonempty numeric vector)
# [76] -> FAILED (Argument mu must be a nonempty numeric vector)
# [77] -> FAILED (Argument mu must be a nonempty numeric vector)
# [78] -> FAILED (Argument mu must be a nonempty numeric vector)
# [79] -> FAILED (Argument mu must be a nonempty numeric vector)
# [80] -> FAILED (Argument mu must be a nonempty numeric vector)
# [81] -> FAILED (Argument mu must be a nonempty numeric vector)
# [82] -> FAILED (Argument mu must be a nonempty numeric vector)
# [83] -> FAILED (Argument mu must be a nonempty numeric vector)
# [84] -> FAILED (must have 'max' > 'min')
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
# [91] -> FAILED (Argument mu must be a nonempty numeric vector)
# [92] -> FAILED (Argument mu must be a nonempty numeric vector)
# [93] -> FAILED (Argument mu must be a nonempty numeric vector)
# [94] -> FAILED (Argument mu must be a nonempty numeric vector)
# [95] -> FAILED (Argument mu must be a nonempty numeric vector)
# [96] -> FAILED (Argument mu must be a nonempty numeric vector)
# [97] -> FAILED (Argument mu must be a nonempty numeric vector)
# [98] -> FAILED (Argument mu must be a nonempty numeric vector)
# [99] -> FAILED (Argument mu must be a nonempty numeric vector)
# [100] -> FAILED (Argument mu must be a nonempty numeric vector)
# [101] -> FAILED (Argument mu must be a nonempty numeric vector)
# [102] -> FAILED (Argument mu must be a nonempty numeric vector)
# [103] -> FAILED (Argument mu must be a nonempty numeric vector)
# [104] -> FAILED (Argument mu must be a nonempty numeric vector)
# [105] -> FAILED (Argument mu must be a nonempty numeric vector)
# [106] -> FAILED (Argument mu must be a nonempty numeric vector)
# [107] -> FAILED (Argument mu must be a nonempty numeric vector)
# [108] -> FAILED (Argument mu must be a nonempty numeric vector)
# [109] -> FAILED (Argument mu must be a nonempty numeric vector)
# [110] -> FAILED (Argument mu must be a nonempty numeric vector)
# [111] -> FAILED (Argument mu must be a nonempty numeric vector)
# [112] -> FAILED (must have 'max' > 'min')
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
# [119] -> FAILED (Argument mu must be a nonempty numeric vector)
# [120] -> FAILED (Argument mu must be a nonempty numeric vector)
# [121] -> FAILED (Argument mu must be a nonempty numeric vector)
# [122] -> FAILED (Argument mu must be a nonempty numeric vector)
# [123] -> FAILED (Argument mu must be a nonempty numeric vector)
# [124] -> FAILED (Argument mu must be a nonempty numeric vector)
# [125] -> FAILED (Argument mu must be a nonempty numeric vector)
# [126] -> FAILED (Argument mu must be a nonempty numeric vector)
# [127] -> FAILED (Argument mu must be a nonempty numeric vector)
# [128] -> FAILED (Argument mu must be a nonempty numeric vector)
# [129] -> FAILED (Argument mu must be a nonempty numeric vector)
# [130] -> FAILED (Argument mu must be a nonempty numeric vector)
# [131] -> FAILED (Argument mu must be a nonempty numeric vector)
# [132] -> FAILED (Argument mu must be a nonempty numeric vector)
# [133] -> FAILED (Argument mu must be a nonempty numeric vector)
# [134] -> FAILED (Argument mu must be a nonempty numeric vector)
# [135] -> FAILED (Argument mu must be a nonempty numeric vector)
# [136] -> FAILED (Argument mu must be a nonempty numeric vector)
# [137] -> FAILED (Argument mu must be a nonempty numeric vector)
# [138] -> FAILED (Argument mu must be a nonempty numeric vector)
# [139] -> FAILED (Argument mu must be a nonempty numeric vector)
# [140] -> FAILED (must have 'max' > 'min')
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
# [147] -> FAILED (Argument mu must be a nonempty numeric vector)
# [148] -> FAILED (Argument mu must be a nonempty numeric vector)
# [149] -> FAILED (Argument mu must be a nonempty numeric vector)
# [150] -> FAILED (Argument mu must be a nonempty numeric vector)
# [151] -> FAILED (Argument mu must be a nonempty numeric vector)
# [152] -> FAILED (Argument mu must be a nonempty numeric vector)
# [153] -> FAILED (Argument mu must be a nonempty numeric vector)
# [154] -> FAILED (Argument mu must be a nonempty numeric vector)
# [155] -> FAILED (Argument mu must be a nonempty numeric vector)
# [156] -> FAILED (Argument mu must be a nonempty numeric vector)
# [157] -> FAILED (Argument mu must be a nonempty numeric vector)
# [158] -> FAILED (Argument mu must be a nonempty numeric vector)
# [159] -> FAILED (Argument mu must be a nonempty numeric vector)
# [160] -> FAILED (Argument mu must be a nonempty numeric vector)
# [161] -> FAILED (Argument mu must be a nonempty numeric vector)
# [162] -> FAILED (Argument mu must be a nonempty numeric vector)
# [163] -> FAILED (Argument mu must be a nonempty numeric vector)
# [164] -> FAILED (Argument mu must be a nonempty numeric vector)
# [165] -> FAILED (Argument mu must be a nonempty numeric vector)
# [166] -> FAILED (Argument mu must be a nonempty numeric vector)
# [167] -> FAILED (Argument mu must be a nonempty numeric vector)
# [168] -> FAILED (must have 'max' > 'min')
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
# [175] -> FAILED (Argument mu must be a nonempty numeric vector)
# [176] -> FAILED (Argument mu must be a nonempty numeric vector)
# [177] -> FAILED (Argument mu must be a nonempty numeric vector)
# [178] -> FAILED (Argument mu must be a nonempty numeric vector)
# [179] -> FAILED (Argument mu must be a nonempty numeric vector)
# [180] -> FAILED (Argument mu must be a nonempty numeric vector)
# [181] -> FAILED (Argument mu must be a nonempty numeric vector)
# [182] -> FAILED (Argument mu must be a nonempty numeric vector)
# [183] -> FAILED (Argument mu must be a nonempty numeric vector)
# [184] -> FAILED (Argument mu must be a nonempty numeric vector)
# [185] -> FAILED (Argument mu must be a nonempty numeric vector)
# [186] -> FAILED (Argument mu must be a nonempty numeric vector)
# [187] -> FAILED (Argument mu must be a nonempty numeric vector)
# [188] -> FAILED (Argument mu must be a nonempty numeric vector)
# [189] -> FAILED (Argument mu must be a nonempty numeric vector)
# [190] -> FAILED (Argument mu must be a nonempty numeric vector)
# [191] -> FAILED (Argument mu must be a nonempty numeric vector)
# [192] -> FAILED (Argument mu must be a nonempty numeric vector)
# [193] -> FAILED (Argument mu must be a nonempty numeric vector)
# [194] -> FAILED (Argument mu must be a nonempty numeric vector)
# [195] -> FAILED (Argument mu must be a nonempty numeric vector)
# [196] -> FAILED (must have 'max' > 'min')
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
# [203] -> FAILED (Argument mu must be a nonempty numeric vector)
# [204] -> FAILED (Argument mu must be a nonempty numeric vector)
# [205] -> FAILED (Argument mu must be a nonempty numeric vector)
# [206] -> FAILED (Argument mu must be a nonempty numeric vector)
# [207] -> FAILED (Argument mu must be a nonempty numeric vector)
# [208] -> FAILED (Argument mu must be a nonempty numeric vector)
# [209] -> FAILED (Argument mu must be a nonempty numeric vector)
# [210] -> FAILED (Argument mu must be a nonempty numeric vector)
# [211] -> FAILED (Argument mu must be a nonempty numeric vector)
# [212] -> FAILED (Argument mu must be a nonempty numeric vector)
# [213] -> FAILED (Argument mu must be a nonempty numeric vector)
# [214] -> FAILED (Argument mu must be a nonempty numeric vector)
# [215] -> FAILED (Argument mu must be a nonempty numeric vector)
# [216] -> FAILED (Argument mu must be a nonempty numeric vector)
# [217] -> FAILED (Argument mu must be a nonempty numeric vector)
# [218] -> FAILED (Argument mu must be a nonempty numeric vector)
# [219] -> FAILED (Argument mu must be a nonempty numeric vector)
# [220] -> FAILED (Argument mu must be a nonempty numeric vector)
# [221] -> FAILED (Argument mu must be a nonempty numeric vector)
# [222] -> FAILED (Argument mu must be a nonempty numeric vector)
# [223] -> FAILED (Argument mu must be a nonempty numeric vector)
# [224] -> FAILED (must have 'max' > 'min')
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
# [231] -> FAILED (Argument mu must be a nonempty numeric vector)
# [232] -> FAILED (Argument mu must be a nonempty numeric vector)
# [233] -> FAILED (Argument mu must be a nonempty numeric vector)
# [234] -> FAILED (Argument mu must be a nonempty numeric vector)
# [235] -> FAILED (Argument mu must be a nonempty numeric vector)
# [236] -> FAILED (Argument mu must be a nonempty numeric vector)
# [237] -> FAILED (Argument mu must be a nonempty numeric vector)
# [238] -> FAILED (Argument mu must be a nonempty numeric vector)
# [239] -> FAILED (Argument mu must be a nonempty numeric vector)
# [240] -> FAILED (Argument mu must be a nonempty numeric vector)
# [241] -> FAILED (Argument mu must be a nonempty numeric vector)
# [242] -> FAILED (Argument mu must be a nonempty numeric vector)
# [243] -> FAILED (Argument mu must be a nonempty numeric vector)
# [244] -> FAILED (Argument mu must be a nonempty numeric vector)
# [245] -> FAILED (Argument mu must be a nonempty numeric vector)
# [246] -> FAILED (Argument mu must be a nonempty numeric vector)
# [247] -> FAILED (Argument mu must be a nonempty numeric vector)
# [248] -> FAILED (Argument mu must be a nonempty numeric vector)
# [249] -> FAILED (Argument mu must be a nonempty numeric vector)
# [250] -> FAILED (Argument mu must be a nonempty numeric vector)
# [251] -> FAILED (Argument mu must be a nonempty numeric vector)
# [252] -> FAILED (must have 'max' > 'min')
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
# [259] -> FAILED (Argument mu must be a nonempty numeric vector)
# [260] -> FAILED (Argument mu must be a nonempty numeric vector)
# [261] -> FAILED (Argument mu must be a nonempty numeric vector)
# [262] -> FAILED (Argument mu must be a nonempty numeric vector)
# [263] -> FAILED (Argument mu must be a nonempty numeric vector)
# [264] -> FAILED (Argument mu must be a nonempty numeric vector)
# [265] -> FAILED (Argument mu must be a nonempty numeric vector)
# [266] -> FAILED (Argument mu must be a nonempty numeric vector)
# [267] -> FAILED (Argument mu must be a nonempty numeric vector)
# [268] -> FAILED (Argument mu must be a nonempty numeric vector)
# [269] -> FAILED (Argument mu must be a nonempty numeric vector)
# [270] -> FAILED (Argument mu must be a nonempty numeric vector)
# [271] -> FAILED (Argument mu must be a nonempty numeric vector)
# [272] -> FAILED (Argument mu must be a nonempty numeric vector)
# [273] -> FAILED (Argument mu must be a nonempty numeric vector)
# [274] -> FAILED (Argument mu must be a nonempty numeric vector)
# [275] -> FAILED (Argument mu must be a nonempty numeric vector)
# [276] -> FAILED (Argument mu must be a nonempty numeric vector)
# [277] -> FAILED (Argument mu must be a nonempty numeric vector)
# [278] -> FAILED (Argument mu must be a nonempty numeric vector)
# [279] -> FAILED (Argument mu must be a nonempty numeric vector)
# [280] -> FAILED (must have 'max' > 'min')
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
# [287] -> FAILED (Argument mu must be a nonempty numeric vector)
# [288] -> FAILED (Argument mu must be a nonempty numeric vector)
# [289] -> FAILED (Argument mu must be a nonempty numeric vector)
# [290] -> FAILED (Argument mu must be a nonempty numeric vector)
# [291] -> FAILED (Argument mu must be a nonempty numeric vector)
# [292] -> FAILED (Argument mu must be a nonempty numeric vector)
# [293] -> FAILED (Argument mu must be a nonempty numeric vector)
# [294] -> FAILED (Argument mu must be a nonempty numeric vector)
# [295] -> FAILED (Argument mu must be a nonempty numeric vector)
# [296] -> FAILED (Argument mu must be a nonempty numeric vector)
# [297] -> FAILED (Argument mu must be a nonempty numeric vector)
# [298] -> FAILED (Argument mu must be a nonempty numeric vector)
# [299] -> FAILED (Argument mu must be a nonempty numeric vector)
# [300] -> FAILED (Argument mu must be a nonempty numeric vector)
# [301] -> FAILED (Argument mu must be a nonempty numeric vector)
# [302] -> FAILED (Argument mu must be a nonempty numeric vector)
# [303] -> FAILED (Argument mu must be a nonempty numeric vector)
# [304] -> FAILED (Argument mu must be a nonempty numeric vector)
# [305] -> FAILED (Argument mu must be a nonempty numeric vector)
# [306] -> FAILED (Argument mu must be a nonempty numeric vector)
# [307] -> FAILED (Argument mu must be a nonempty numeric vector)
# [308] -> FAILED (must have 'max' > 'min')
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
# [315] -> FAILED (Argument mu must be a nonempty numeric vector)
# [316] -> FAILED (Argument mu must be a nonempty numeric vector)
# [317] -> FAILED (Argument mu must be a nonempty numeric vector)
# [318] -> FAILED (Argument mu must be a nonempty numeric vector)
# [319] -> FAILED (Argument mu must be a nonempty numeric vector)
# [320] -> FAILED (Argument mu must be a nonempty numeric vector)
# [321] -> FAILED (Argument mu must be a nonempty numeric vector)
# [322] -> FAILED (Argument mu must be a nonempty numeric vector)
# [323] -> FAILED (Argument mu must be a nonempty numeric vector)
# [324] -> FAILED (Argument mu must be a nonempty numeric vector)
# [325] -> FAILED (Argument mu must be a nonempty numeric vector)
# [326] -> FAILED (Argument mu must be a nonempty numeric vector)
# [327] -> FAILED (Argument mu must be a nonempty numeric vector)
# [328] -> FAILED (Argument mu must be a nonempty numeric vector)
# [329] -> FAILED (Argument mu must be a nonempty numeric vector)
# [330] -> FAILED (Argument mu must be a nonempty numeric vector)
# [331] -> FAILED (Argument mu must be a nonempty numeric vector)
# [332] -> FAILED (Argument mu must be a nonempty numeric vector)
# [333] -> FAILED (Argument mu must be a nonempty numeric vector)
# [334] -> FAILED (Argument mu must be a nonempty numeric vector)
# [335] -> FAILED (Argument mu must be a nonempty numeric vector)
# [336] -> FAILED (must have 'max' > 'min')
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
# [343] -> FAILED (Argument mu must be a nonempty numeric vector)
# [344] -> FAILED (Argument mu must be a nonempty numeric vector)
# [345] -> FAILED (Argument mu must be a nonempty numeric vector)
# [346] -> FAILED (Argument mu must be a nonempty numeric vector)
# [347] -> FAILED (Argument mu must be a nonempty numeric vector)
# [348] -> FAILED (Argument mu must be a nonempty numeric vector)
# [349] -> FAILED (Argument mu must be a nonempty numeric vector)
# [350] -> FAILED (Argument mu must be a nonempty numeric vector)
# [351] -> FAILED (Argument mu must be a nonempty numeric vector)
# [352] -> FAILED (Argument mu must be a nonempty numeric vector)
# [353] -> FAILED (Argument mu must be a nonempty numeric vector)
# [354] -> FAILED (Argument mu must be a nonempty numeric vector)
# [355] -> FAILED (Argument mu must be a nonempty numeric vector)
# [356] -> FAILED (Argument mu must be a nonempty numeric vector)
# [357] -> FAILED (Argument mu must be a nonempty numeric vector)
# [358] -> FAILED (Argument mu must be a nonempty numeric vector)
# [359] -> FAILED (Argument mu must be a nonempty numeric vector)
# [360] -> FAILED (Argument mu must be a nonempty numeric vector)
# [361] -> FAILED (Argument mu must be a nonempty numeric vector)
# [362] -> FAILED (Argument mu must be a nonempty numeric vector)
# [363] -> FAILED (Argument mu must be a nonempty numeric vector)
# [364] -> FAILED (must have 'max' > 'min')
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
# [371] -> FAILED (Argument mu must be a nonempty numeric vector)
# [372] -> FAILED (Argument mu must be a nonempty numeric vector)
# [373] -> FAILED (Argument mu must be a nonempty numeric vector)
# [374] -> FAILED (Argument mu must be a nonempty numeric vector)
# [375] -> FAILED (Argument mu must be a nonempty numeric vector)
# [376] -> FAILED (Argument mu must be a nonempty numeric vector)
# [377] -> FAILED (Argument mu must be a nonempty numeric vector)
# [378] -> FAILED (Argument mu must be a nonempty numeric vector)
# [379] -> FAILED (Argument mu must be a nonempty numeric vector)
# [380] -> FAILED (Argument mu must be a nonempty numeric vector)
# [381] -> FAILED (Argument mu must be a nonempty numeric vector)
# [382] -> FAILED (Argument mu must be a nonempty numeric vector)
# [383] -> FAILED (Argument mu must be a nonempty numeric vector)
# [384] -> FAILED (Argument mu must be a nonempty numeric vector)
# [385] -> FAILED (Argument mu must be a nonempty numeric vector)
# [386] -> FAILED (Argument mu must be a nonempty numeric vector)
# [387] -> FAILED (Argument mu must be a nonempty numeric vector)
# [388] -> FAILED (Argument mu must be a nonempty numeric vector)
# [389] -> FAILED (Argument mu must be a nonempty numeric vector)
# [390] -> FAILED (Argument mu must be a nonempty numeric vector)
# [391] -> FAILED (Argument mu must be a nonempty numeric vector)
# [392] -> FAILED (must have 'max' > 'min')
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
# [399] -> FAILED (Argument mu must be a nonempty numeric vector)
# [400] -> FAILED (Argument mu must be a nonempty numeric vector)
# [401] -> FAILED (Argument mu must be a nonempty numeric vector)
# [402] -> FAILED (Argument mu must be a nonempty numeric vector)
# [403] -> FAILED (Argument mu must be a nonempty numeric vector)
# [404] -> FAILED (Argument mu must be a nonempty numeric vector)
# [405] -> FAILED (Argument mu must be a nonempty numeric vector)
# [406] -> FAILED (Argument mu must be a nonempty numeric vector)
# [407] -> FAILED (Argument mu must be a nonempty numeric vector)
# [408] -> FAILED (Argument mu must be a nonempty numeric vector)
# [409] -> FAILED (Argument mu must be a nonempty numeric vector)
# [410] -> FAILED (Argument mu must be a nonempty numeric vector)
# [411] -> FAILED (Argument mu must be a nonempty numeric vector)
# [412] -> FAILED (Argument mu must be a nonempty numeric vector)
# [413] -> FAILED (Argument mu must be a nonempty numeric vector)
# [414] -> FAILED (Argument mu must be a nonempty numeric vector)
# [415] -> FAILED (Argument mu must be a nonempty numeric vector)
# [416] -> FAILED (Argument mu must be a nonempty numeric vector)
# [417] -> FAILED (Argument mu must be a nonempty numeric vector)
# [418] -> FAILED (Argument mu must be a nonempty numeric vector)
# [419] -> FAILED (Argument mu must be a nonempty numeric vector)
# [420] -> FAILED (must have 'max' > 'min')
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
# [427] -> FAILED (Argument mu must be a nonempty numeric vector)
# [428] -> FAILED (Argument mu must be a nonempty numeric vector)
# [429] -> FAILED (Argument mu must be a nonempty numeric vector)
# [430] -> FAILED (Argument mu must be a nonempty numeric vector)
# [431] -> FAILED (Argument mu must be a nonempty numeric vector)
# [432] -> FAILED (Argument mu must be a nonempty numeric vector)
# [433] -> FAILED (Argument mu must be a nonempty numeric vector)
# [434] -> FAILED (Argument mu must be a nonempty numeric vector)
# [435] -> FAILED (Argument mu must be a nonempty numeric vector)
# [436] -> FAILED (Argument mu must be a nonempty numeric vector)
# [437] -> FAILED (Argument mu must be a nonempty numeric vector)
# [438] -> FAILED (Argument mu must be a nonempty numeric vector)
# [439] -> FAILED (Argument mu must be a nonempty numeric vector)
# [440] -> FAILED (Argument mu must be a nonempty numeric vector)
# [441] -> FAILED (Argument mu must be a nonempty numeric vector)
# [442] -> FAILED (Argument mu must be a nonempty numeric vector)
# [443] -> FAILED (Argument mu must be a nonempty numeric vector)
# [444] -> FAILED (Argument mu must be a nonempty numeric vector)
# [445] -> FAILED (Argument mu must be a nonempty numeric vector)
# [446] -> FAILED (Argument mu must be a nonempty numeric vector)
# [447] -> FAILED (Argument mu must be a nonempty numeric vector)
# [448] -> FAILED (must have 'max' > 'min')
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
# [455] -> FAILED (Argument mu must be a nonempty numeric vector)
# [456] -> FAILED (Argument mu must be a nonempty numeric vector)
# [457] -> FAILED (Argument mu must be a nonempty numeric vector)
# [458] -> FAILED (Argument mu must be a nonempty numeric vector)
# [459] -> FAILED (Argument mu must be a nonempty numeric vector)
# [460] -> FAILED (Argument mu must be a nonempty numeric vector)
# [461] -> FAILED (Argument mu must be a nonempty numeric vector)
# [462] -> FAILED (Argument mu must be a nonempty numeric vector)
# [463] -> FAILED (Argument mu must be a nonempty numeric vector)
# [464] -> FAILED (Argument mu must be a nonempty numeric vector)
# [465] -> FAILED (Argument mu must be a nonempty numeric vector)
# [466] -> FAILED (Argument mu must be a nonempty numeric vector)
# [467] -> FAILED (Argument mu must be a nonempty numeric vector)
# [468] -> FAILED (Argument mu must be a nonempty numeric vector)
# [469] -> FAILED (Argument mu must be a nonempty numeric vector)
# [470] -> FAILED (Argument mu must be a nonempty numeric vector)
# [471] -> FAILED (Argument mu must be a nonempty numeric vector)
# [472] -> FAILED (Argument mu must be a nonempty numeric vector)
# [473] -> FAILED (Argument mu must be a nonempty numeric vector)
# [474] -> FAILED (Argument mu must be a nonempty numeric vector)
# [475] -> FAILED (Argument mu must be a nonempty numeric vector)
# [476] -> FAILED (must have 'max' > 'min')
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
# [483] -> FAILED (Argument mu must be a nonempty numeric vector)
# [484] -> FAILED (Argument mu must be a nonempty numeric vector)
# [485] -> FAILED (Argument mu must be a nonempty numeric vector)
# [486] -> FAILED (Argument mu must be a nonempty numeric vector)
# [487] -> FAILED (Argument mu must be a nonempty numeric vector)
# [488] -> FAILED (Argument mu must be a nonempty numeric vector)
# [489] -> FAILED (Argument mu must be a nonempty numeric vector)
# [490] -> FAILED (Argument mu must be a nonempty numeric vector)
# [491] -> FAILED (Argument mu must be a nonempty numeric vector)
# [492] -> FAILED (Argument mu must be a nonempty numeric vector)
# [493] -> FAILED (Argument mu must be a nonempty numeric vector)
# [494] -> FAILED (Argument mu must be a nonempty numeric vector)
# [495] -> FAILED (Argument mu must be a nonempty numeric vector)
# [496] -> FAILED (Argument mu must be a nonempty numeric vector)
# [497] -> FAILED (Argument mu must be a nonempty numeric vector)
# [498] -> FAILED (Argument mu must be a nonempty numeric vector)
# [499] -> FAILED (Argument mu must be a nonempty numeric vector)
# [500] -> FAILED (Argument mu must be a nonempty numeric vector)
# [501] -> FAILED (Argument mu must be a nonempty numeric vector)
# [502] -> FAILED (Argument mu must be a nonempty numeric vector)
# [503] -> FAILED (Argument mu must be a nonempty numeric vector)
# [504] -> FAILED (must have 'max' > 'min')
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
# [511] -> FAILED (Argument mu must be a nonempty numeric vector)
# [512] -> FAILED (Argument mu must be a nonempty numeric vector)
# [513] -> FAILED (Argument mu must be a nonempty numeric vector)
# [514] -> FAILED (Argument mu must be a nonempty numeric vector)
# [515] -> FAILED (Argument mu must be a nonempty numeric vector)
# [516] -> FAILED (Argument mu must be a nonempty numeric vector)
# [517] -> FAILED (Argument mu must be a nonempty numeric vector)
# [518] -> FAILED (Argument mu must be a nonempty numeric vector)
# [519] -> FAILED (Argument mu must be a nonempty numeric vector)
# [520] -> FAILED (Argument mu must be a nonempty numeric vector)
# [521] -> FAILED (Argument mu must be a nonempty numeric vector)
# [522] -> FAILED (Argument mu must be a nonempty numeric vector)
# [523] -> FAILED (Argument mu must be a nonempty numeric vector)
# [524] -> FAILED (Argument mu must be a nonempty numeric vector)
# [525] -> FAILED (Argument mu must be a nonempty numeric vector)
# [526] -> FAILED (Argument mu must be a nonempty numeric vector)
# [527] -> FAILED (Argument mu must be a nonempty numeric vector)
# [528] -> FAILED (Argument mu must be a nonempty numeric vector)
# [529] -> FAILED (Argument mu must be a nonempty numeric vector)
# [530] -> FAILED (Argument mu must be a nonempty numeric vector)
# [531] -> FAILED (Argument mu must be a nonempty numeric vector)
# [532] -> FAILED (must have 'max' > 'min')
# training | Wiki | gpt2 -> writing: /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/training/Wiki/gpt2/idiolect_results.xlsx
# training | Wiki | gpt2 -> OK
# training | Enron | gpt2 -> MISSING input: /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/training/Enron/gpt2/raw_agg_adjusted_token_size_scores.rds
# training | Perverted Justice | gpt2 -> MISSING input: /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/training/Perverted Justice/gpt2/raw_agg_adjusted_token_size_scores.rds
# training | StackExchange | gpt2 -> MISSING input: /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/training/StackExchange/gpt2/raw_agg_adjusted_token_size_scores.rds
# training | ACL | gpt2 -> MISSING input: /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/training/ACL/gpt2/raw_agg_adjusted_token_size_scores.rds
# training | TripAdvisor | gpt2 -> MISSING input: /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/training/TripAdvisor/gpt2/raw_agg_adjusted_token_size_scores.rds
# training | The Apricity | gpt2 -> MISSING input: /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/training/The Apricity/gpt2/raw_agg_adjusted_token_size_scores.rds
# training | Koppel's Blogs | gpt2 -> MISSING input: /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/training/Koppel's Blogs/gpt2/raw_agg_adjusted_token_size_scores.rds
# training | The Telegraph | gpt2 -> MISSING input: /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/training/The Telegraph/gpt2/raw_agg_adjusted_token_size_scores.rds
# training | Reddit | gpt2 -> MISSING input: /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/training/Reddit/gpt2/raw_agg_adjusted_token_size_scores.rds
# training | Enron Cleaned | gpt2 -> reading: /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/training/Enron Cleaned/gpt2/raw_agg_adjusted_token_size_scores.rds
# training | Enron Cleaned | gpt2 -> calculating performance
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |                                                                      |   0%[8] -> FAILED (Argument mu must be a nonempty numeric vector)
# [9] -> FAILED (Argument mu must be a nonempty numeric vector)
# [10] -> FAILED (Argument mu must be a nonempty numeric vector)
# [11] -> FAILED (Argument mu must be a nonempty numeric vector)
# [12] -> FAILED (Argument mu must be a nonempty numeric vector)
# [13] -> FAILED (Argument mu must be a nonempty numeric vector)
# [14] -> FAILED (Argument mu must be a nonempty numeric vector)
# [15] -> FAILED (Argument mu must be a nonempty numeric vector)
# [16] -> FAILED (Argument mu must be a nonempty numeric vector)
# [17] -> FAILED (Argument mu must be a nonempty numeric vector)
# [18] -> FAILED (Argument mu must be a nonempty numeric vector)
# [19] -> FAILED (Argument mu must be a nonempty numeric vector)
# [20] -> FAILED (Argument mu must be a nonempty numeric vector)
# [21] -> FAILED (must have 'max' > 'min')
# [22] -> FAILED (must have 'max' > 'min')
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |                                                                      |   0%[30] -> FAILED (Argument mu must be a nonempty numeric vector)
# [31] -> FAILED (Argument mu must be a nonempty numeric vector)
# [32] -> FAILED (Argument mu must be a nonempty numeric vector)
# [33] -> FAILED (Argument mu must be a nonempty numeric vector)
# [34] -> FAILED (Argument mu must be a nonempty numeric vector)
# [35] -> FAILED (Argument mu must be a nonempty numeric vector)
# [36] -> FAILED (Argument mu must be a nonempty numeric vector)
# [37] -> FAILED (Argument mu must be a nonempty numeric vector)
# [38] -> FAILED (Argument mu must be a nonempty numeric vector)
# [39] -> FAILED (Argument mu must be a nonempty numeric vector)
# [40] -> FAILED (Argument mu must be a nonempty numeric vector)
# [41] -> FAILED (Argument mu must be a nonempty numeric vector)
# [42] -> FAILED (Argument mu must be a nonempty numeric vector)
# [43] -> FAILED (must have 'max' > 'min')
# [44] -> FAILED (must have 'max' > 'min')
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |                                                                      |   0%[52] -> FAILED (Argument mu must be a nonempty numeric vector)
# [53] -> FAILED (Argument mu must be a nonempty numeric vector)
# [54] -> FAILED (Argument mu must be a nonempty numeric vector)
# [55] -> FAILED (Argument mu must be a nonempty numeric vector)
# [56] -> FAILED (Argument mu must be a nonempty numeric vector)
# [57] -> FAILED (Argument mu must be a nonempty numeric vector)
# [58] -> FAILED (Argument mu must be a nonempty numeric vector)
# [59] -> FAILED (Argument mu must be a nonempty numeric vector)
# [60] -> FAILED (Argument mu must be a nonempty numeric vector)
# [61] -> FAILED (Argument mu must be a nonempty numeric vector)
# [62] -> FAILED (Argument mu must be a nonempty numeric vector)
# [63] -> FAILED (Argument mu must be a nonempty numeric vector)
# [64] -> FAILED (Argument mu must be a nonempty numeric vector)
# [65] -> FAILED (must have 'max' > 'min')
# [66] -> FAILED (must have 'max' > 'min')
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |                                                                      |   0%[74] -> FAILED (Argument mu must be a nonempty numeric vector)
# [75] -> FAILED (Argument mu must be a nonempty numeric vector)
# [76] -> FAILED (Argument mu must be a nonempty numeric vector)
# [77] -> FAILED (Argument mu must be a nonempty numeric vector)
# [78] -> FAILED (Argument mu must be a nonempty numeric vector)
# [79] -> FAILED (Argument mu must be a nonempty numeric vector)
# [80] -> FAILED (Argument mu must be a nonempty numeric vector)
# [81] -> FAILED (Argument mu must be a nonempty numeric vector)
# [82] -> FAILED (Argument mu must be a nonempty numeric vector)
# [83] -> FAILED (Argument mu must be a nonempty numeric vector)
# [84] -> FAILED (Argument mu must be a nonempty numeric vector)
# [85] -> FAILED (Argument mu must be a nonempty numeric vector)
# [86] -> FAILED (Argument mu must be a nonempty numeric vector)
# [87] -> FAILED (must have 'max' > 'min')
# [88] -> FAILED (must have 'max' > 'min')
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |                                                                      |   0%[96] -> FAILED (Argument mu must be a nonempty numeric vector)
# [97] -> FAILED (Argument mu must be a nonempty numeric vector)
# [98] -> FAILED (Argument mu must be a nonempty numeric vector)
# [99] -> FAILED (Argument mu must be a nonempty numeric vector)
# [100] -> FAILED (Argument mu must be a nonempty numeric vector)
# [101] -> FAILED (Argument mu must be a nonempty numeric vector)
# [102] -> FAILED (Argument mu must be a nonempty numeric vector)
# [103] -> FAILED (Argument mu must be a nonempty numeric vector)
# [104] -> FAILED (Argument mu must be a nonempty numeric vector)
# [105] -> FAILED (Argument mu must be a nonempty numeric vector)
# [106] -> FAILED (Argument mu must be a nonempty numeric vector)
# [107] -> FAILED (Argument mu must be a nonempty numeric vector)
# [108] -> FAILED (Argument mu must be a nonempty numeric vector)
# [109] -> FAILED (must have 'max' > 'min')
# [110] -> FAILED (must have 'max' > 'min')
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |                                                                      |   0%[118] -> FAILED (Argument mu must be a nonempty numeric vector)
# [119] -> FAILED (Argument mu must be a nonempty numeric vector)
# [120] -> FAILED (Argument mu must be a nonempty numeric vector)
# [121] -> FAILED (Argument mu must be a nonempty numeric vector)
# [122] -> FAILED (Argument mu must be a nonempty numeric vector)
# [123] -> FAILED (Argument mu must be a nonempty numeric vector)
# [124] -> FAILED (Argument mu must be a nonempty numeric vector)
# [125] -> FAILED (Argument mu must be a nonempty numeric vector)
# [126] -> FAILED (Argument mu must be a nonempty numeric vector)
# [127] -> FAILED (Argument mu must be a nonempty numeric vector)
# [128] -> FAILED (Argument mu must be a nonempty numeric vector)
# [129] -> FAILED (Argument mu must be a nonempty numeric vector)
# [130] -> FAILED (Argument mu must be a nonempty numeric vector)
# [131] -> FAILED (must have 'max' > 'min')
# [132] -> FAILED (must have 'max' > 'min')
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |                                                                      |   0%[140] -> FAILED (Argument mu must be a nonempty numeric vector)
# [141] -> FAILED (Argument mu must be a nonempty numeric vector)
# [142] -> FAILED (Argument mu must be a nonempty numeric vector)
# [143] -> FAILED (Argument mu must be a nonempty numeric vector)
# [144] -> FAILED (Argument mu must be a nonempty numeric vector)
# [145] -> FAILED (Argument mu must be a nonempty numeric vector)
# [146] -> FAILED (Argument mu must be a nonempty numeric vector)
# ...
# [150] -> FAILED (Argument mu must be a nonempty numeric vector)
# [151] -> FAILED (Argument mu must be a nonempty numeric vector)
# [152] -> FAILED (must have 'max' > 'min')
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |========================================================              |  80%[162] -> FAILED (Argument mu must be a nonempty numeric vector)
# [163] -> FAILED (Argument mu must be a nonempty numeric vector)
# [164] -> FAILED (Argument mu must be a nonempty numeric vector)
# [165] -> FAILED (Argument mu must be a nonempty numeric vector)
# [166] -> FAILED (Argument mu must be a nonempty numeric vector)
# [167] -> FAILED (Argument mu must be a nonempty numeric vector)
# [168] -> FAILED (Argument mu must be a nonempty numeric vector)
# [169] -> FAILED (Argument mu must be a nonempty numeric vector)
# [170] -> FAILED (Argument mu must be a nonempty numeric vector)
# [171] -> FAILED (must have 'max' > 'min')
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |========================================================              |  80%[181] -> FAILED (Argument mu must be a nonempty numeric vector)
# [182] -> FAILED (Argument mu must be a nonempty numeric vector)
# [183] -> FAILED (Argument mu must be a nonempty numeric vector)
# [184] -> FAILED (Argument mu must be a nonempty numeric vector)
# [185] -> FAILED (Argument mu must be a nonempty numeric vector)
# [186] -> FAILED (Argument mu must be a nonempty numeric vector)
# [187] -> FAILED (Argument mu must be a nonempty numeric vector)
# [188] -> FAILED (Argument mu must be a nonempty numeric vector)
# [189] -> FAILED (Argument mu must be a nonempty numeric vector)
# [190] -> FAILED (must have 'max' > 'min')
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |========================================================              |  80%[200] -> FAILED (Argument mu must be a nonempty numeric vector)
# [201] -> FAILED (Argument mu must be a nonempty numeric vector)
# [202] -> FAILED (Argument mu must be a nonempty numeric vector)
# [203] -> FAILED (Argument mu must be a nonempty numeric vector)
# [204] -> FAILED (Argument mu must be a nonempty numeric vector)
# [205] -> FAILED (Argument mu must be a nonempty numeric vector)
# [206] -> FAILED (Argument mu must be a nonempty numeric vector)
# [207] -> FAILED (Argument mu must be a nonempty numeric vector)
# [208] -> FAILED (Argument mu must be a nonempty numeric vector)
# [209] -> FAILED (must have 'max' > 'min')
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |========================================================              |  80%[219] -> FAILED (Argument mu must be a nonempty numeric vector)
# [220] -> FAILED (Argument mu must be a nonempty numeric vector)
# [221] -> FAILED (Argument mu must be a nonempty numeric vector)
# [222] -> FAILED (Argument mu must be a nonempty numeric vector)
# [223] -> FAILED (Argument mu must be a nonempty numeric vector)
# [224] -> FAILED (Argument mu must be a nonempty numeric vector)
# [225] -> FAILED (Argument mu must be a nonempty numeric vector)
# [226] -> FAILED (Argument mu must be a nonempty numeric vector)
# [227] -> FAILED (Argument mu must be a nonempty numeric vector)
# [228] -> FAILED (must have 'max' > 'min')
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |========================================================              |  80%[238] -> FAILED (Argument mu must be a nonempty numeric vector)
# [239] -> FAILED (Argument mu must be a nonempty numeric vector)
# [240] -> FAILED (Argument mu must be a nonempty numeric vector)
# [241] -> FAILED (Argument mu must be a nonempty numeric vector)
# [242] -> FAILED (Argument mu must be a nonempty numeric vector)
# [243] -> FAILED (Argument mu must be a nonempty numeric vector)
# [244] -> FAILED (Argument mu must be a nonempty numeric vector)
# [245] -> FAILED (Argument mu must be a nonempty numeric vector)
# [246] -> FAILED (Argument mu must be a nonempty numeric vector)
# [247] -> FAILED (must have 'max' > 'min')
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |========================================================              |  80%[257] -> FAILED (Argument mu must be a nonempty numeric vector)
# [258] -> FAILED (Argument mu must be a nonempty numeric vector)
# [259] -> FAILED (Argument mu must be a nonempty numeric vector)
# [260] -> FAILED (Argument mu must be a nonempty numeric vector)
# [261] -> FAILED (Argument mu must be a nonempty numeric vector)
# [262] -> FAILED (Argument mu must be a nonempty numeric vector)
# [263] -> FAILED (Argument mu must be a nonempty numeric vector)
# [264] -> FAILED (Argument mu must be a nonempty numeric vector)
# [265] -> FAILED (Argument mu must be a nonempty numeric vector)
# [266] -> FAILED (must have 'max' > 'min')
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |========================================================              |  80%[276] -> FAILED (Argument mu must be a nonempty numeric vector)
# [277] -> FAILED (Argument mu must be a nonempty numeric vector)
# [278] -> FAILED (Argument mu must be a nonempty numeric vector)
# [279] -> FAILED (Argument mu must be a nonempty numeric vector)
# [280] -> FAILED (Argument mu must be a nonempty numeric vector)
# [281] -> FAILED (Argument mu must be a nonempty numeric vector)
# [282] -> FAILED (Argument mu must be a nonempty numeric vector)
# [283] -> FAILED (Argument mu must be a nonempty numeric vector)
# [284] -> FAILED (Argument mu must be a nonempty numeric vector)
# [285] -> FAILED (must have 'max' > 'min')
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |========================================================              |  80%[295] -> FAILED (Argument mu must be a nonempty numeric vector)
# [296] -> FAILED (Argument mu must be a nonempty numeric vector)
# [297] -> FAILED (Argument mu must be a nonempty numeric vector)
# [298] -> FAILED (Argument mu must be a nonempty numeric vector)
# [299] -> FAILED (Argument mu must be a nonempty numeric vector)
# [300] -> FAILED (Argument mu must be a nonempty numeric vector)
# [301] -> FAILED (Argument mu must be a nonempty numeric vector)
# [302] -> FAILED (Argument mu must be a nonempty numeric vector)
# [303] -> FAILED (Argument mu must be a nonempty numeric vector)
# [304] -> FAILED (must have 'max' > 'min')
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |========================================================              |  80%[314] -> FAILED (Argument mu must be a nonempty numeric vector)
# [315] -> FAILED (Argument mu must be a nonempty numeric vector)
# [316] -> FAILED (Argument mu must be a nonempty numeric vector)
# [317] -> FAILED (Argument mu must be a nonempty numeric vector)
# [318] -> FAILED (Argument mu must be a nonempty numeric vector)
# [319] -> FAILED (Argument mu must be a nonempty numeric vector)
# [320] -> FAILED (Argument mu must be a nonempty numeric vector)
# [321] -> FAILED (Argument mu must be a nonempty numeric vector)
# [322] -> FAILED (Argument mu must be a nonempty numeric vector)
# [323] -> FAILED (must have 'max' > 'min')
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |========================================================              |  80%[333] -> FAILED (Argument mu must be a nonempty numeric vector)
# [334] -> FAILED (Argument mu must be a nonempty numeric vector)
# [335] -> FAILED (Argument mu must be a nonempty numeric vector)
# [336] -> FAILED (Argument mu must be a nonempty numeric vector)
# [337] -> FAILED (Argument mu must be a nonempty numeric vector)
# [338] -> FAILED (Argument mu must be a nonempty numeric vector)
# [339] -> FAILED (Argument mu must be a nonempty numeric vector)
# [340] -> FAILED (Argument mu must be a nonempty numeric vector)
# [341] -> FAILED (Argument mu must be a nonempty numeric vector)
# [342] -> FAILED (must have 'max' > 'min')
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |========================================================              |  80%[352] -> FAILED (Argument mu must be a nonempty numeric vector)
# [353] -> FAILED (Argument mu must be a nonempty numeric vector)
# [354] -> FAILED (Argument mu must be a nonempty numeric vector)
# [355] -> FAILED (Argument mu must be a nonempty numeric vector)
# [356] -> FAILED (Argument mu must be a nonempty numeric vector)
# [357] -> FAILED (Argument mu must be a nonempty numeric vector)
# [358] -> FAILED (Argument mu must be a nonempty numeric vector)
# [359] -> FAILED (Argument mu must be a nonempty numeric vector)
# [360] -> FAILED (Argument mu must be a nonempty numeric vector)
# [361] -> FAILED (must have 'max' > 'min')
# test | Enron Cleaned | gpt2 -> writing: /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/test/Enron Cleaned/gpt2/idiolect_results.xlsx
# test | Enron Cleaned | gpt2 -> OK

# %%
for (corpus in corpora) {
  for (model_name in models) {

    # paths
    test_file_loc <- file.path(base_loc, "test", corpus, model_name, file_name)
    train_file_loc <- file.path(base_loc, "training", corpus, model_name, file_name)

    save_loc <- file.path(base_loc, "test", corpus, model_name, calibrated_save_name)

    prefix <- sprintf("%s | %s", corpus, model_name)

    # skip if already saved
    # if (file.exists(save_loc)) {
    #   message(prefix, " -> SKIP (exists): ", save_loc)
    #   next
    # }

    # skip if either input missing (need BOTH)
    if (!file.exists(test_file_loc) || !file.exists(train_file_loc)) {
      message(prefix, " -> SKIP (missing inputs) test_exists=",
              file.exists(test_file_loc), " training_exists=", file.exists(train_file_loc))
      next
    }

    tryCatch(
      {
        message(prefix, " -> reading test: ", test_file_loc)
        test_df <- readRDS(test_file_loc)

        message(prefix, " -> reading training: ", train_file_loc)
        training_df <- readRDS(train_file_loc)

        message(prefix, " -> calculating performance (calibrated)")
        # uses your calculate_performance(test_df, training_df=..., ...)
        results <- calculate_calibrated_performance(test_df = test_df, training_df = training_df)

        if (is.null(results) || nrow(results) == 0) {
          message(prefix, " -> NO RESULTS (empty), not writing")
          next
        }

        dir.create(dirname(save_loc), recursive = TRUE, showWarnings = FALSE)

        message(prefix, " -> writing: ", save_loc)
        writexl::write_xlsx(results, save_loc)

        message(prefix, " -> OK")
      },
      error = function(e) {
        message(prefix, " -> FAILED: ", conditionMessage(e))
      }
    )
  }
}
# Out:
# Wiki | gpt2 -> reading test: /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/test/Wiki/gpt2/raw_agg_adjusted_token_size_scores.rds
# Wiki | gpt2 -> reading training: /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/training/Wiki/gpt2/raw_agg_adjusted_token_size_scores.rds
# Wiki | gpt2 -> calculating performance (calibrated)
# [7] -> FAILED (Argument mu must be a nonempty numeric vector)
# [8] -> FAILED (Argument mu must be a nonempty numeric vector)
# [9] -> FAILED (Argument mu must be a nonempty numeric vector)
# [10] -> FAILED (Argument mu must be a nonempty numeric vector)
# [11] -> SKIP (no matching training rows)
# [12] -> FAILED (Argument mu must be a nonempty numeric vector)
# [13] -> SKIP (no matching training rows)
# [14] -> SKIP (no matching training rows)
# [15] -> SKIP (no matching training rows)
# [16] -> FAILED (Argument mu must be a nonempty numeric vector)
# [17] -> SKIP (no matching training rows)
# [18] -> FAILED (Argument mu must be a nonempty numeric vector)
# [19] -> SKIP (no matching training rows)
# [20] -> FAILED (Argument mu must be a nonempty numeric vector)
# [21] -> FAILED (Argument mu must be a nonempty numeric vector)
# [22] -> SKIP (no matching training rows)
# [23] -> SKIP (no matching training rows)
# [24] -> SKIP (no matching training rows)
# [25] -> SKIP (no matching training rows)
# [26] -> SKIP (no matching training rows)
# [27] -> FAILED (Argument mu must be a nonempty numeric vector)
# [28] -> SKIP (no matching training rows)
# [29] -> SKIP (no matching training rows)
# [30] -> SKIP (no matching training rows)
# [31] -> SKIP (no matching training rows)
# [32] -> SKIP (no matching training rows)
# [33] -> SKIP (no matching training rows)
# [40] -> FAILED (Argument mu must be a nonempty numeric vector)
# [41] -> FAILED (Argument mu must be a nonempty numeric vector)
# [42] -> FAILED (Argument mu must be a nonempty numeric vector)
# [43] -> FAILED (Argument mu must be a nonempty numeric vector)
# [44] -> SKIP (no matching training rows)
# [45] -> FAILED (Argument mu must be a nonempty numeric vector)
# [46] -> SKIP (no matching training rows)
# [47] -> SKIP (no matching training rows)
# [48] -> SKIP (no matching training rows)
# [49] -> FAILED (Argument mu must be a nonempty numeric vector)
# [50] -> SKIP (no matching training rows)
# [51] -> FAILED (Argument mu must be a nonempty numeric vector)
# [52] -> SKIP (no matching training rows)
# [53] -> FAILED (Argument mu must be a nonempty numeric vector)
# [54] -> FAILED (Argument mu must be a nonempty numeric vector)
# [55] -> SKIP (no matching training rows)
# [56] -> SKIP (no matching training rows)
# [57] -> SKIP (no matching training rows)
# [58] -> SKIP (no matching training rows)
# [59] -> SKIP (no matching training rows)
# [60] -> FAILED (Argument mu must be a nonempty numeric vector)
# [61] -> SKIP (no matching training rows)
# [62] -> SKIP (no matching training rows)
# [63] -> SKIP (no matching training rows)
# [64] -> SKIP (no matching training rows)
# [65] -> SKIP (no matching training rows)
# [66] -> SKIP (no matching training rows)
# [73] -> FAILED (Argument mu must be a nonempty numeric vector)
# [74] -> FAILED (Argument mu must be a nonempty numeric vector)
# [75] -> FAILED (Argument mu must be a nonempty numeric vector)
# [76] -> FAILED (Argument mu must be a nonempty numeric vector)
# [77] -> SKIP (no matching training rows)
# [78] -> FAILED (Argument mu must be a nonempty numeric vector)
# [79] -> SKIP (no matching training rows)
# [80] -> SKIP (no matching training rows)
# [81] -> SKIP (no matching training rows)
# [82] -> FAILED (Argument mu must be a nonempty numeric vector)
# [83] -> SKIP (no matching training rows)
# [84] -> FAILED (Argument mu must be a nonempty numeric vector)
# [85] -> SKIP (no matching training rows)
# [86] -> FAILED (Argument mu must be a nonempty numeric vector)
# [87] -> FAILED (Argument mu must be a nonempty numeric vector)
# [88] -> SKIP (no matching training rows)
# [89] -> SKIP (no matching training rows)
# [90] -> SKIP (no matching training rows)
# [91] -> SKIP (no matching training rows)
# [92] -> SKIP (no matching training rows)
# [93] -> FAILED (Argument mu must be a nonempty numeric vector)
# [94] -> SKIP (no matching training rows)
# [95] -> SKIP (no matching training rows)
# [96] -> SKIP (no matching training rows)
# [97] -> SKIP (no matching training rows)
# [98] -> SKIP (no matching training rows)
# [99] -> SKIP (no matching training rows)
# [106] -> FAILED (Argument mu must be a nonempty numeric vector)
# [107] -> FAILED (Argument mu must be a nonempty numeric vector)
# [108] -> FAILED (Argument mu must be a nonempty numeric vector)
# [109] -> FAILED (Argument mu must be a nonempty numeric vector)
# [110] -> SKIP (no matching training rows)
# [111] -> FAILED (Argument mu must be a nonempty numeric vector)
# [112] -> SKIP (no matching training rows)
# [113] -> SKIP (no matching training rows)
# [114] -> SKIP (no matching training rows)
# [115] -> FAILED (Argument mu must be a nonempty numeric vector)
# [116] -> SKIP (no matching training rows)
# [117] -> FAILED (Argument mu must be a nonempty numeric vector)
# [118] -> SKIP (no matching training rows)
# [119] -> FAILED (Argument mu must be a nonempty numeric vector)
# [120] -> FAILED (Argument mu must be a nonempty numeric vector)
# [121] -> SKIP (no matching training rows)
# [122] -> SKIP (no matching training rows)
# [123] -> SKIP (no matching training rows)
# [124] -> SKIP (no matching training rows)
# [125] -> SKIP (no matching training rows)
# [126] -> FAILED (Argument mu must be a nonempty numeric vector)
# [127] -> SKIP (no matching training rows)
# [128] -> SKIP (no matching training rows)
# [129] -> SKIP (no matching training rows)
# [130] -> SKIP (no matching training rows)
# [131] -> SKIP (no matching training rows)
# [132] -> SKIP (no matching training rows)
# [139] -> FAILED (Argument mu must be a nonempty numeric vector)
# [140] -> FAILED (Argument mu must be a nonempty numeric vector)
# [141] -> FAILED (Argument mu must be a nonempty numeric vector)
# [142] -> FAILED (Argument mu must be a nonempty numeric vector)
# [143] -> SKIP (no matching training rows)
# [144] -> FAILED (Argument mu must be a nonempty numeric vector)
# [145] -> SKIP (no matching training rows)
# [146] -> SKIP (no matching training rows)
# [147] -> SKIP (no matching training rows)
# [148] -> FAILED (Argument mu must be a nonempty numeric vector)
# [149] -> SKIP (no matching training rows)
# [150] -> FAILED (Argument mu must be a nonempty numeric vector)
# [151] -> SKIP (no matching training rows)
# [152] -> FAILED (Argument mu must be a nonempty numeric vector)
# [153] -> FAILED (Argument mu must be a nonempty numeric vector)
# [154] -> SKIP (no matching training rows)
# [155] -> SKIP (no matching training rows)
# [156] -> SKIP (no matching training rows)
# [157] -> SKIP (no matching training rows)
# [158] -> SKIP (no matching training rows)
# [159] -> FAILED (Argument mu must be a nonempty numeric vector)
# [160] -> SKIP (no matching training rows)
# [161] -> SKIP (no matching training rows)
# [162] -> SKIP (no matching training rows)
# [163] -> SKIP (no matching training rows)
# [164] -> SKIP (no matching training rows)
# [165] -> SKIP (no matching training rows)
# [172] -> FAILED (Argument mu must be a nonempty numeric vector)
# [173] -> FAILED (Argument mu must be a nonempty numeric vector)
# [174] -> FAILED (Argument mu must be a nonempty numeric vector)
# [175] -> FAILED (Argument mu must be a nonempty numeric vector)
# [176] -> SKIP (no matching training rows)
# [177] -> FAILED (Argument mu must be a nonempty numeric vector)
# [178] -> SKIP (no matching training rows)
# [179] -> SKIP (no matching training rows)
# [180] -> SKIP (no matching training rows)
# [181] -> FAILED (Argument mu must be a nonempty numeric vector)
# [182] -> SKIP (no matching training rows)
# [183] -> FAILED (Argument mu must be a nonempty numeric vector)
# [184] -> SKIP (no matching training rows)
# [185] -> FAILED (Argument mu must be a nonempty numeric vector)
# [186] -> FAILED (Argument mu must be a nonempty numeric vector)
# [187] -> SKIP (no matching training rows)
# [188] -> SKIP (no matching training rows)
# [189] -> SKIP (no matching training rows)
# [190] -> SKIP (no matching training rows)
# [191] -> SKIP (no matching training rows)
# [192] -> FAILED (Argument mu must be a nonempty numeric vector)
# [193] -> SKIP (no matching training rows)
# [194] -> SKIP (no matching training rows)
# [195] -> SKIP (no matching training rows)
# [196] -> SKIP (no matching training rows)
# [197] -> SKIP (no matching training rows)
# [198] -> SKIP (no matching training rows)
# [205] -> FAILED (Argument mu must be a nonempty numeric vector)
# [206] -> FAILED (Argument mu must be a nonempty numeric vector)
# [207] -> FAILED (Argument mu must be a nonempty numeric vector)
# [208] -> FAILED (Argument mu must be a nonempty numeric vector)
# [209] -> SKIP (no matching training rows)
# [210] -> FAILED (Argument mu must be a nonempty numeric vector)
# [211] -> SKIP (no matching training rows)
# [212] -> SKIP (no matching training rows)
# [213] -> SKIP (no matching training rows)
# [214] -> FAILED (Argument mu must be a nonempty numeric vector)
# [215] -> SKIP (no matching training rows)
# [216] -> FAILED (Argument mu must be a nonempty numeric vector)
# [217] -> SKIP (no matching training rows)
# [218] -> FAILED (Argument mu must be a nonempty numeric vector)
# [219] -> FAILED (Argument mu must be a nonempty numeric vector)
# [220] -> SKIP (no matching training rows)
# [221] -> SKIP (no matching training rows)
# [222] -> SKIP (no matching training rows)
# [223] -> SKIP (no matching training rows)
# [224] -> SKIP (no matching training rows)
# [225] -> FAILED (Argument mu must be a nonempty numeric vector)
# [226] -> SKIP (no matching training rows)
# [227] -> SKIP (no matching training rows)
# [228] -> SKIP (no matching training rows)
# [229] -> SKIP (no matching training rows)
# [230] -> SKIP (no matching training rows)
# [231] -> SKIP (no matching training rows)
# [238] -> FAILED (Argument mu must be a nonempty numeric vector)
# [239] -> FAILED (Argument mu must be a nonempty numeric vector)
# [240] -> FAILED (Argument mu must be a nonempty numeric vector)
# [241] -> FAILED (Argument mu must be a nonempty numeric vector)
# [242] -> SKIP (no matching training rows)
# [243] -> FAILED (Argument mu must be a nonempty numeric vector)
# [244] -> SKIP (no matching training rows)
# [245] -> SKIP (no matching training rows)
# [246] -> SKIP (no matching training rows)
# [247] -> FAILED (Argument mu must be a nonempty numeric vector)
# [248] -> SKIP (no matching training rows)
# [249] -> FAILED (Argument mu must be a nonempty numeric vector)
# [250] -> SKIP (no matching training rows)
# [251] -> FAILED (Argument mu must be a nonempty numeric vector)
# [252] -> FAILED (Argument mu must be a nonempty numeric vector)
# [253] -> SKIP (no matching training rows)
# [254] -> SKIP (no matching training rows)
# [255] -> SKIP (no matching training rows)
# [256] -> SKIP (no matching training rows)
# [257] -> SKIP (no matching training rows)
# [258] -> FAILED (Argument mu must be a nonempty numeric vector)
# [259] -> SKIP (no matching training rows)
# [260] -> SKIP (no matching training rows)
# [261] -> SKIP (no matching training rows)
# [262] -> SKIP (no matching training rows)
# [263] -> SKIP (no matching training rows)
# [264] -> SKIP (no matching training rows)
# [271] -> FAILED (Argument mu must be a nonempty numeric vector)
# [272] -> FAILED (Argument mu must be a nonempty numeric vector)
# [273] -> FAILED (Argument mu must be a nonempty numeric vector)
# [274] -> FAILED (Argument mu must be a nonempty numeric vector)
# [275] -> SKIP (no matching training rows)
# [276] -> FAILED (Argument mu must be a nonempty numeric vector)
# [277] -> SKIP (no matching training rows)
# [278] -> SKIP (no matching training rows)
# [279] -> SKIP (no matching training rows)
# [280] -> FAILED (Argument mu must be a nonempty numeric vector)
# [281] -> SKIP (no matching training rows)
# [282] -> FAILED (Argument mu must be a nonempty numeric vector)
# [283] -> SKIP (no matching training rows)
# [284] -> FAILED (Argument mu must be a nonempty numeric vector)
# [285] -> FAILED (Argument mu must be a nonempty numeric vector)
# [286] -> SKIP (no matching training rows)
# [287] -> SKIP (no matching training rows)
# [288] -> SKIP (no matching training rows)
# [289] -> SKIP (no matching training rows)
# [290] -> SKIP (no matching training rows)
# [291] -> FAILED (Argument mu must be a nonempty numeric vector)
# [292] -> SKIP (no matching training rows)
# [293] -> SKIP (no matching training rows)
# [294] -> SKIP (no matching training rows)
# [295] -> SKIP (no matching training rows)
# [296] -> SKIP (no matching training rows)
# [297] -> SKIP (no matching training rows)
# [304] -> FAILED (Argument mu must be a nonempty numeric vector)
# [305] -> FAILED (Argument mu must be a nonempty numeric vector)
# [306] -> FAILED (Argument mu must be a nonempty numeric vector)
# [307] -> FAILED (Argument mu must be a nonempty numeric vector)
# [308] -> SKIP (no matching training rows)
# [309] -> FAILED (Argument mu must be a nonempty numeric vector)
# [310] -> SKIP (no matching training rows)
# [311] -> SKIP (no matching training rows)
# [312] -> SKIP (no matching training rows)
# [313] -> FAILED (Argument mu must be a nonempty numeric vector)
# [314] -> SKIP (no matching training rows)
# [315] -> FAILED (Argument mu must be a nonempty numeric vector)
# [316] -> SKIP (no matching training rows)
# [317] -> FAILED (Argument mu must be a nonempty numeric vector)
# [318] -> FAILED (Argument mu must be a nonempty numeric vector)
# [319] -> SKIP (no matching training rows)
# [320] -> SKIP (no matching training rows)
# [321] -> SKIP (no matching training rows)
# [322] -> SKIP (no matching training rows)
# [323] -> SKIP (no matching training rows)
# [324] -> FAILED (Argument mu must be a nonempty numeric vector)
# [325] -> SKIP (no matching training rows)
# [326] -> SKIP (no matching training rows)
# [327] -> SKIP (no matching training rows)
# [328] -> SKIP (no matching training rows)
# [329] -> SKIP (no matching training rows)
# [330] -> SKIP (no matching training rows)
# [337] -> FAILED (Argument mu must be a nonempty numeric vector)
# [338] -> FAILED (Argument mu must be a nonempty numeric vector)
# [339] -> FAILED (Argument mu must be a nonempty numeric vector)
# [340] -> FAILED (Argument mu must be a nonempty numeric vector)
# [341] -> SKIP (no matching training rows)
# [342] -> FAILED (Argument mu must be a nonempty numeric vector)
# [343] -> SKIP (no matching training rows)
# [344] -> SKIP (no matching training rows)
# [345] -> SKIP (no matching training rows)
# [346] -> FAILED (Argument mu must be a nonempty numeric vector)
# [347] -> SKIP (no matching training rows)
# [348] -> FAILED (Argument mu must be a nonempty numeric vector)
# [349] -> SKIP (no matching training rows)
# [350] -> FAILED (Argument mu must be a nonempty numeric vector)
# [351] -> FAILED (Argument mu must be a nonempty numeric vector)
# [352] -> SKIP (no matching training rows)
# [353] -> SKIP (no matching training rows)
# [354] -> SKIP (no matching training rows)
# [355] -> SKIP (no matching training rows)
# [356] -> SKIP (no matching training rows)
# [357] -> FAILED (Argument mu must be a nonempty numeric vector)
# [358] -> SKIP (no matching training rows)
# [359] -> SKIP (no matching training rows)
# [360] -> SKIP (no matching training rows)
# [361] -> SKIP (no matching training rows)
# [362] -> SKIP (no matching training rows)
# [363] -> SKIP (no matching training rows)
# [370] -> FAILED (Argument mu must be a nonempty numeric vector)
# [371] -> FAILED (Argument mu must be a nonempty numeric vector)
# [372] -> FAILED (Argument mu must be a nonempty numeric vector)
# [373] -> FAILED (Argument mu must be a nonempty numeric vector)
# [374] -> SKIP (no matching training rows)
# [375] -> FAILED (Argument mu must be a nonempty numeric vector)
# [376] -> SKIP (no matching training rows)
# [377] -> SKIP (no matching training rows)
# [378] -> SKIP (no matching training rows)
# [379] -> FAILED (Argument mu must be a nonempty numeric vector)
# [380] -> SKIP (no matching training rows)
# [381] -> FAILED (Argument mu must be a nonempty numeric vector)
# [382] -> SKIP (no matching training rows)
# [383] -> FAILED (Argument mu must be a nonempty numeric vector)
# [384] -> FAILED (Argument mu must be a nonempty numeric vector)
# [385] -> SKIP (no matching training rows)
# [386] -> SKIP (no matching training rows)
# [387] -> SKIP (no matching training rows)
# [388] -> SKIP (no matching training rows)
# [389] -> SKIP (no matching training rows)
# [390] -> FAILED (Argument mu must be a nonempty numeric vector)
# [391] -> SKIP (no matching training rows)
# [392] -> SKIP (no matching training rows)
# [393] -> SKIP (no matching training rows)
# [394] -> SKIP (no matching training rows)
# [395] -> SKIP (no matching training rows)
# [396] -> SKIP (no matching training rows)
# [403] -> FAILED (Argument mu must be a nonempty numeric vector)
# [404] -> FAILED (Argument mu must be a nonempty numeric vector)
# [405] -> FAILED (Argument mu must be a nonempty numeric vector)
# [406] -> FAILED (Argument mu must be a nonempty numeric vector)
# [407] -> SKIP (no matching training rows)
# [408] -> FAILED (Argument mu must be a nonempty numeric vector)
# [409] -> SKIP (no matching training rows)
# [410] -> SKIP (no matching training rows)
# [411] -> SKIP (no matching training rows)
# [412] -> FAILED (Argument mu must be a nonempty numeric vector)
# [413] -> SKIP (no matching training rows)
# [414] -> FAILED (Argument mu must be a nonempty numeric vector)
# [415] -> SKIP (no matching training rows)
# [416] -> FAILED (Argument mu must be a nonempty numeric vector)
# [417] -> FAILED (Argument mu must be a nonempty numeric vector)
# [418] -> SKIP (no matching training rows)
# [419] -> SKIP (no matching training rows)
# [420] -> SKIP (no matching training rows)
# [421] -> SKIP (no matching training rows)
# [422] -> SKIP (no matching training rows)
# [423] -> FAILED (Argument mu must be a nonempty numeric vector)
# [424] -> SKIP (no matching training rows)
# [425] -> SKIP (no matching training rows)
# [426] -> SKIP (no matching training rows)
# [427] -> SKIP (no matching training rows)
# [428] -> SKIP (no matching training rows)
# [429] -> SKIP (no matching training rows)
# [436] -> FAILED (Argument mu must be a nonempty numeric vector)
# [437] -> FAILED (Argument mu must be a nonempty numeric vector)
# [438] -> FAILED (Argument mu must be a nonempty numeric vector)
# [439] -> FAILED (Argument mu must be a nonempty numeric vector)
# [440] -> SKIP (no matching training rows)
# [441] -> FAILED (Argument mu must be a nonempty numeric vector)
# [442] -> SKIP (no matching training rows)
# [443] -> SKIP (no matching training rows)
# [444] -> SKIP (no matching training rows)
# [445] -> FAILED (Argument mu must be a nonempty numeric vector)
# [446] -> SKIP (no matching training rows)
# [447] -> FAILED (Argument mu must be a nonempty numeric vector)
# [448] -> SKIP (no matching training rows)
# [449] -> FAILED (Argument mu must be a nonempty numeric vector)
# [450] -> FAILED (Argument mu must be a nonempty numeric vector)
# [451] -> SKIP (no matching training rows)
# [452] -> SKIP (no matching training rows)
# [453] -> SKIP (no matching training rows)
# [454] -> SKIP (no matching training rows)
# [455] -> SKIP (no matching training rows)
# [456] -> FAILED (Argument mu must be a nonempty numeric vector)
# [457] -> SKIP (no matching training rows)
# [458] -> SKIP (no matching training rows)
# [459] -> SKIP (no matching training rows)
# [460] -> SKIP (no matching training rows)
# [461] -> SKIP (no matching training rows)
# [462] -> SKIP (no matching training rows)
# [469] -> FAILED (Argument mu must be a nonempty numeric vector)
# [470] -> FAILED (Argument mu must be a nonempty numeric vector)
# [471] -> FAILED (Argument mu must be a nonempty numeric vector)
# [472] -> FAILED (Argument mu must be a nonempty numeric vector)
# [473] -> SKIP (no matching training rows)
# [474] -> FAILED (Argument mu must be a nonempty numeric vector)
# [475] -> SKIP (no matching training rows)
# [476] -> SKIP (no matching training rows)
# [477] -> SKIP (no matching training rows)
# [478] -> FAILED (Argument mu must be a nonempty numeric vector)
# [479] -> SKIP (no matching training rows)
# [480] -> FAILED (Argument mu must be a nonempty numeric vector)
# [481] -> SKIP (no matching training rows)
# [482] -> FAILED (Argument mu must be a nonempty numeric vector)
# [483] -> FAILED (Argument mu must be a nonempty numeric vector)
# [484] -> SKIP (no matching training rows)
# [485] -> SKIP (no matching training rows)
# [486] -> SKIP (no matching training rows)
# [487] -> SKIP (no matching training rows)
# [488] -> SKIP (no matching training rows)
# [489] -> FAILED (Argument mu must be a nonempty numeric vector)
# [490] -> SKIP (no matching training rows)
# [491] -> SKIP (no matching training rows)
# [492] -> SKIP (no matching training rows)
# [493] -> SKIP (no matching training rows)
# [494] -> SKIP (no matching training rows)
# [495] -> SKIP (no matching training rows)
# [502] -> FAILED (Argument mu must be a nonempty numeric vector)
# [503] -> FAILED (Argument mu must be a nonempty numeric vector)
# [504] -> FAILED (Argument mu must be a nonempty numeric vector)
# [505] -> FAILED (Argument mu must be a nonempty numeric vector)
# [506] -> SKIP (no matching training rows)
# [507] -> FAILED (Argument mu must be a nonempty numeric vector)
# [508] -> SKIP (no matching training rows)
# [509] -> SKIP (no matching training rows)
# [510] -> SKIP (no matching training rows)
# [511] -> FAILED (Argument mu must be a nonempty numeric vector)
# [512] -> SKIP (no matching training rows)
# [513] -> FAILED (Argument mu must be a nonempty numeric vector)
# [514] -> SKIP (no matching training rows)
# [515] -> FAILED (Argument mu must be a nonempty numeric vector)
# [516] -> FAILED (Argument mu must be a nonempty numeric vector)
# [517] -> SKIP (no matching training rows)
# [518] -> SKIP (no matching training rows)
# [519] -> SKIP (no matching training rows)
# [520] -> SKIP (no matching training rows)
# [521] -> SKIP (no matching training rows)
# [522] -> FAILED (Argument mu must be a nonempty numeric vector)
# [523] -> SKIP (no matching training rows)
# [524] -> SKIP (no matching training rows)
# [525] -> SKIP (no matching training rows)
# [526] -> SKIP (no matching training rows)
# [527] -> SKIP (no matching training rows)
# [528] -> SKIP (no matching training rows)
# [535] -> FAILED (Argument mu must be a nonempty numeric vector)
# [536] -> FAILED (Argument mu must be a nonempty numeric vector)
# [537] -> FAILED (Argument mu must be a nonempty numeric vector)
# [538] -> FAILED (Argument mu must be a nonempty numeric vector)
# [539] -> SKIP (no matching training rows)
# [540] -> FAILED (Argument mu must be a nonempty numeric vector)
# [541] -> SKIP (no matching training rows)
# [542] -> SKIP (no matching training rows)
# [543] -> SKIP (no matching training rows)
# [544] -> FAILED (Argument mu must be a nonempty numeric vector)
# [545] -> SKIP (no matching training rows)
# [546] -> FAILED (Argument mu must be a nonempty numeric vector)
# [547] -> SKIP (no matching training rows)
# [548] -> FAILED (Argument mu must be a nonempty numeric vector)
# [549] -> FAILED (Argument mu must be a nonempty numeric vector)
# [550] -> SKIP (no matching training rows)
# [551] -> SKIP (no matching training rows)
# [552] -> SKIP (no matching training rows)
# [553] -> SKIP (no matching training rows)
# [554] -> SKIP (no matching training rows)
# [555] -> FAILED (Argument mu must be a nonempty numeric vector)
# [556] -> SKIP (no matching training rows)
# [557] -> SKIP (no matching training rows)
# [558] -> SKIP (no matching training rows)
# [559] -> SKIP (no matching training rows)
# [560] -> SKIP (no matching training rows)
# [561] -> SKIP (no matching training rows)
# [568] -> FAILED (Argument mu must be a nonempty numeric vector)
# [569] -> FAILED (Argument mu must be a nonempty numeric vector)
# [570] -> FAILED (Argument mu must be a nonempty numeric vector)
# [571] -> FAILED (Argument mu must be a nonempty numeric vector)
# [572] -> SKIP (no matching training rows)
# [573] -> FAILED (Argument mu must be a nonempty numeric vector)
# [574] -> SKIP (no matching training rows)
# [575] -> SKIP (no matching training rows)
# [576] -> SKIP (no matching training rows)
# [577] -> FAILED (Argument mu must be a nonempty numeric vector)
# [578] -> SKIP (no matching training rows)
# [579] -> FAILED (Argument mu must be a nonempty numeric vector)
# [580] -> SKIP (no matching training rows)
# [581] -> FAILED (Argument mu must be a nonempty numeric vector)
# [582] -> FAILED (Argument mu must be a nonempty numeric vector)
# [583] -> SKIP (no matching training rows)
# [584] -> SKIP (no matching training rows)
# [585] -> SKIP (no matching training rows)
# [586] -> SKIP (no matching training rows)
# [587] -> SKIP (no matching training rows)
# [588] -> FAILED (Argument mu must be a nonempty numeric vector)
# [589] -> SKIP (no matching training rows)
# [590] -> SKIP (no matching training rows)
# [591] -> SKIP (no matching training rows)
# [592] -> SKIP (no matching training rows)
# [593] -> SKIP (no matching training rows)
# [594] -> SKIP (no matching training rows)
# [601] -> FAILED (Argument mu must be a nonempty numeric vector)
# [602] -> FAILED (Argument mu must be a nonempty numeric vector)
# [603] -> FAILED (Argument mu must be a nonempty numeric vector)
# [604] -> FAILED (Argument mu must be a nonempty numeric vector)
# [605] -> SKIP (no matching training rows)
# [606] -> FAILED (Argument mu must be a nonempty numeric vector)
# [607] -> SKIP (no matching training rows)
# [608] -> SKIP (no matching training rows)
# [609] -> SKIP (no matching training rows)
# [610] -> FAILED (Argument mu must be a nonempty numeric vector)
# [611] -> SKIP (no matching training rows)
# [612] -> FAILED (Argument mu must be a nonempty numeric vector)
# [613] -> SKIP (no matching training rows)
# [614] -> FAILED (Argument mu must be a nonempty numeric vector)
# [615] -> FAILED (Argument mu must be a nonempty numeric vector)
# [616] -> SKIP (no matching training rows)
# [617] -> SKIP (no matching training rows)
# [618] -> SKIP (no matching training rows)
# [619] -> SKIP (no matching training rows)
# [620] -> SKIP (no matching training rows)
# [621] -> FAILED (Argument mu must be a nonempty numeric vector)
# [622] -> SKIP (no matching training rows)
# [623] -> SKIP (no matching training rows)
# [624] -> SKIP (no matching training rows)
# [625] -> SKIP (no matching training rows)
# [626] -> SKIP (no matching training rows)
# [627] -> SKIP (no matching training rows)
# Wiki | gpt2 -> writing: /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/test/Wiki/gpt2/idiolect_calibrated_results.xlsx
# Wiki | gpt2 -> OK
# Enron | gpt2 -> SKIP (missing inputs) test_exists=FALSE training_exists=FALSE
# Perverted Justice | gpt2 -> SKIP (missing inputs) test_exists=FALSE training_exists=FALSE
# StackExchange | gpt2 -> SKIP (missing inputs) test_exists=FALSE training_exists=FALSE
# ACL | gpt2 -> SKIP (missing inputs) test_exists=FALSE training_exists=FALSE
# TripAdvisor | gpt2 -> SKIP (missing inputs) test_exists=FALSE training_exists=FALSE
# The Apricity | gpt2 -> SKIP (missing inputs) test_exists=FALSE training_exists=FALSE
# Koppel's Blogs | gpt2 -> SKIP (missing inputs) test_exists=FALSE training_exists=FALSE
# The Telegraph | gpt2 -> SKIP (missing inputs) test_exists=FALSE training_exists=FALSE
# Reddit | gpt2 -> SKIP (missing inputs) test_exists=FALSE training_exists=FALSE
# Enron Cleaned | gpt2 -> reading test: /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/test/Enron Cleaned/gpt2/raw_agg_adjusted_token_size_scores.rds
# Enron Cleaned | gpt2 -> reading training: /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/training/Enron Cleaned/gpt2/raw_agg_adjusted_token_size_scores.rds
# Enron Cleaned | gpt2 -> calculating performance (calibrated)
# [9] -> FAILED (Argument mu must be a nonempty numeric vector)
# [10] -> FAILED (Argument mu must be a nonempty numeric vector)
# [11] -> FAILED (Argument mu must be a nonempty numeric vector)
# [12] -> FAILED (Argument mu must be a nonempty numeric vector)
# [13] -> FAILED (Argument mu must be a nonempty numeric vector)
# [14] -> FAILED (Argument mu must be a nonempty numeric vector)
# [15] -> SKIP (no matching training rows)
# [16] -> FAILED (Argument mu must be a nonempty numeric vector)
# [17] -> SKIP (no matching training rows)
# [18] -> FAILED (Argument mu must be a nonempty numeric vector)
# [19] -> FAILED (Argument mu must be a nonempty numeric vector)
# [28] -> FAILED (Argument mu must be a nonempty numeric vector)
# [29] -> FAILED (Argument mu must be a nonempty numeric vector)
# [30] -> FAILED (Argument mu must be a nonempty numeric vector)
# [31] -> FAILED (Argument mu must be a nonempty numeric vector)
# [32] -> FAILED (Argument mu must be a nonempty numeric vector)
# [33] -> FAILED (Argument mu must be a nonempty numeric vector)
# [34] -> SKIP (no matching training rows)
# [35] -> FAILED (Argument mu must be a nonempty numeric vector)
# [36] -> SKIP (no matching training rows)
# [37] -> FAILED (Argument mu must be a nonempty numeric vector)
# [38] -> FAILED (Argument mu must be a nonempty numeric vector)
# [47] -> FAILED (Argument mu must be a nonempty numeric vector)
# [48] -> FAILED (Argument mu must be a nonempty numeric vector)
# [49] -> FAILED (Argument mu must be a nonempty numeric vector)
# [50] -> FAILED (Argument mu must be a nonempty numeric vector)
# [51] -> FAILED (Argument mu must be a nonempty numeric vector)
# [52] -> FAILED (Argument mu must be a nonempty numeric vector)
# [53] -> SKIP (no matching training rows)
# [54] -> FAILED (Argument mu must be a nonempty numeric vector)
# [55] -> SKIP (no matching training rows)
# [56] -> FAILED (Argument mu must be a nonempty numeric vector)
# [57] -> FAILED (Argument mu must be a nonempty numeric vector)
# [66] -> FAILED (Argument mu must be a nonempty numeric vector)
# [67] -> FAILED (Argument mu must be a nonempty numeric vector)
# [68] -> FAILED (Argument mu must be a nonempty numeric vector)
# [69] -> FAILED (Argument mu must be a nonempty numeric vector)
# [70] -> FAILED (Argument mu must be a nonempty numeric vector)
# [71] -> FAILED (Argument mu must be a nonempty numeric vector)
# [72] -> SKIP (no matching training rows)
# [73] -> FAILED (Argument mu must be a nonempty numeric vector)
# [74] -> SKIP (no matching training rows)
# [75] -> FAILED (Argument mu must be a nonempty numeric vector)
# [76] -> FAILED (Argument mu must be a nonempty numeric vector)
# [85] -> FAILED (Argument mu must be a nonempty numeric vector)
# [86] -> FAILED (Argument mu must be a nonempty numeric vector)
# [87] -> FAILED (Argument mu must be a nonempty numeric vector)
# [88] -> FAILED (Argument mu must be a nonempty numeric vector)
# [89] -> FAILED (Argument mu must be a nonempty numeric vector)
# [90] -> FAILED (Argument mu must be a nonempty numeric vector)
# [91] -> SKIP (no matching training rows)
# [92] -> FAILED (Argument mu must be a nonempty numeric vector)
# [93] -> SKIP (no matching training rows)
# [94] -> FAILED (Argument mu must be a nonempty numeric vector)
# [95] -> FAILED (Argument mu must be a nonempty numeric vector)
# [104] -> FAILED (Argument mu must be a nonempty numeric vector)
# [105] -> FAILED (Argument mu must be a nonempty numeric vector)
# [106] -> FAILED (Argument mu must be a nonempty numeric vector)
# [107] -> FAILED (Argument mu must be a nonempty numeric vector)
# [108] -> FAILED (Argument mu must be a nonempty numeric vector)
# [109] -> FAILED (Argument mu must be a nonempty numeric vector)
# [110] -> SKIP (no matching training rows)
# [111] -> FAILED (Argument mu must be a nonempty numeric vector)
# [112] -> SKIP (no matching training rows)
# [113] -> FAILED (Argument mu must be a nonempty numeric vector)
# [114] -> FAILED (Argument mu must be a nonempty numeric vector)
# [123] -> FAILED (Argument mu must be a nonempty numeric vector)
# [124] -> FAILED (Argument mu must be a nonempty numeric vector)
# [125] -> FAILED (Argument mu must be a nonempty numeric vector)
# [126] -> FAILED (Argument mu must be a nonempty numeric vector)
# [127] -> FAILED (Argument mu must be a nonempty numeric vector)
# [128] -> FAILED (Argument mu must be a nonempty numeric vector)
# [129] -> SKIP (no matching training rows)
# [130] -> FAILED (Argument mu must be a nonempty numeric vector)
# [131] -> SKIP (no matching training rows)
# [132] -> FAILED (Argument mu must be a nonempty numeric vector)
# [133] -> FAILED (Argument mu must be a nonempty numeric vector)
# [142] -> FAILED (Argument mu must be a nonempty numeric vector)
# [143] -> FAILED (Argument mu must be a nonempty numeric vector)
# [144] -> FAILED (Argument mu must be a nonempty numeric vector)
# [145] -> FAILED (Argument mu must be a nonempty numeric vector)
# [146] -> FAILED (Argument mu must be a nonempty numeric vector)
# [147] -> FAILED (Argument mu must be a nonempty numeric vector)
# [148] -> SKIP (no matching training rows)
# [149] -> FAILED (Argument mu must be a nonempty numeric vector)
# [150] -> SKIP (no matching training rows)
# [151] -> FAILED (Argument mu must be a nonempty numeric vector)
# [152] -> FAILED (Argument mu must be a nonempty numeric vector)
# [161] -> FAILED (Argument mu must be a nonempty numeric vector)
# [162] -> FAILED (Argument mu must be a nonempty numeric vector)
# [163] -> FAILED (Argument mu must be a nonempty numeric vector)
# [164] -> FAILED (Argument mu must be a nonempty numeric vector)
# [165] -> FAILED (Argument mu must be a nonempty numeric vector)
# [166] -> FAILED (Argument mu must be a nonempty numeric vector)
# [167] -> SKIP (no matching training rows)
# [168] -> FAILED (Argument mu must be a nonempty numeric vector)
# [169] -> SKIP (no matching training rows)
# [170] -> FAILED (Argument mu must be a nonempty numeric vector)
# [171] -> FAILED (Argument mu must be a nonempty numeric vector)
# [180] -> FAILED (Argument mu must be a nonempty numeric vector)
# [181] -> FAILED (Argument mu must be a nonempty numeric vector)
# [182] -> FAILED (Argument mu must be a nonempty numeric vector)
# [183] -> FAILED (Argument mu must be a nonempty numeric vector)
# [184] -> FAILED (Argument mu must be a nonempty numeric vector)
# [185] -> FAILED (Argument mu must be a nonempty numeric vector)
# [186] -> SKIP (no matching training rows)
# [187] -> FAILED (Argument mu must be a nonempty numeric vector)
# [188] -> SKIP (no matching training rows)
# [189] -> FAILED (Argument mu must be a nonempty numeric vector)
# [190] -> FAILED (Argument mu must be a nonempty numeric vector)
# [199] -> FAILED (Argument mu must be a nonempty numeric vector)
# [200] -> FAILED (Argument mu must be a nonempty numeric vector)
# [201] -> FAILED (Argument mu must be a nonempty numeric vector)
# [202] -> FAILED (Argument mu must be a nonempty numeric vector)
# [203] -> FAILED (Argument mu must be a nonempty numeric vector)
# [204] -> FAILED (Argument mu must be a nonempty numeric vector)
# [205] -> SKIP (no matching training rows)
# [206] -> FAILED (Argument mu must be a nonempty numeric vector)
# [207] -> SKIP (no matching training rows)
# [208] -> FAILED (Argument mu must be a nonempty numeric vector)
# [209] -> FAILED (Argument mu must be a nonempty numeric vector)
# [218] -> FAILED (Argument mu must be a nonempty numeric vector)
# [219] -> FAILED (Argument mu must be a nonempty numeric vector)
# [220] -> FAILED (Argument mu must be a nonempty numeric vector)
# [221] -> FAILED (Argument mu must be a nonempty numeric vector)
# [222] -> FAILED (Argument mu must be a nonempty numeric vector)
# [223] -> FAILED (Argument mu must be a nonempty numeric vector)
# [224] -> SKIP (no matching training rows)
# [225] -> FAILED (Argument mu must be a nonempty numeric vector)
# [226] -> SKIP (no matching training rows)
# [227] -> FAILED (Argument mu must be a nonempty numeric vector)
# [228] -> FAILED (Argument mu must be a nonempty numeric vector)
# [237] -> FAILED (Argument mu must be a nonempty numeric vector)
# [238] -> FAILED (Argument mu must be a nonempty numeric vector)
# [239] -> FAILED (Argument mu must be a nonempty numeric vector)
# [240] -> FAILED (Argument mu must be a nonempty numeric vector)
# [241] -> FAILED (Argument mu must be a nonempty numeric vector)
# [242] -> FAILED (Argument mu must be a nonempty numeric vector)
# [243] -> SKIP (no matching training rows)
# [244] -> FAILED (Argument mu must be a nonempty numeric vector)
# [245] -> SKIP (no matching training rows)
# [246] -> FAILED (Argument mu must be a nonempty numeric vector)
# [247] -> FAILED (Argument mu must be a nonempty numeric vector)
# [256] -> FAILED (Argument mu must be a nonempty numeric vector)
# [257] -> FAILED (Argument mu must be a nonempty numeric vector)
# [258] -> FAILED (Argument mu must be a nonempty numeric vector)
# [259] -> FAILED (Argument mu must be a nonempty numeric vector)
# [260] -> FAILED (Argument mu must be a nonempty numeric vector)
# [261] -> FAILED (Argument mu must be a nonempty numeric vector)
# [262] -> SKIP (no matching training rows)
# [263] -> FAILED (Argument mu must be a nonempty numeric vector)
# [264] -> SKIP (no matching training rows)
# [265] -> FAILED (Argument mu must be a nonempty numeric vector)
# [266] -> FAILED (Argument mu must be a nonempty numeric vector)
# [275] -> FAILED (Argument mu must be a nonempty numeric vector)
# [276] -> FAILED (Argument mu must be a nonempty numeric vector)
# [277] -> FAILED (Argument mu must be a nonempty numeric vector)
# [278] -> FAILED (Argument mu must be a nonempty numeric vector)
# [279] -> FAILED (Argument mu must be a nonempty numeric vector)
# [280] -> FAILED (Argument mu must be a nonempty numeric vector)
# [281] -> SKIP (no matching training rows)
# [282] -> FAILED (Argument mu must be a nonempty numeric vector)
# [283] -> SKIP (no matching training rows)
# [284] -> FAILED (Argument mu must be a nonempty numeric vector)
# [285] -> FAILED (Argument mu must be a nonempty numeric vector)
# [294] -> FAILED (Argument mu must be a nonempty numeric vector)
# [295] -> FAILED (Argument mu must be a nonempty numeric vector)
# [296] -> FAILED (Argument mu must be a nonempty numeric vector)
# [297] -> FAILED (Argument mu must be a nonempty numeric vector)
# [298] -> FAILED (Argument mu must be a nonempty numeric vector)
# [299] -> FAILED (Argument mu must be a nonempty numeric vector)
# [300] -> SKIP (no matching training rows)
# [301] -> FAILED (Argument mu must be a nonempty numeric vector)
# [302] -> SKIP (no matching training rows)
# [303] -> FAILED (Argument mu must be a nonempty numeric vector)
# [304] -> FAILED (Argument mu must be a nonempty numeric vector)
# [313] -> FAILED (Argument mu must be a nonempty numeric vector)
# [314] -> FAILED (Argument mu must be a nonempty numeric vector)
# [315] -> FAILED (Argument mu must be a nonempty numeric vector)
# [316] -> FAILED (Argument mu must be a nonempty numeric vector)
# [317] -> FAILED (Argument mu must be a nonempty numeric vector)
# [318] -> FAILED (Argument mu must be a nonempty numeric vector)
# [319] -> SKIP (no matching training rows)
# [320] -> FAILED (Argument mu must be a nonempty numeric vector)
# [321] -> SKIP (no matching training rows)
# [322] -> FAILED (Argument mu must be a nonempty numeric vector)
# [323] -> FAILED (Argument mu must be a nonempty numeric vector)
# [332] -> FAILED (Argument mu must be a nonempty numeric vector)
# [333] -> FAILED (Argument mu must be a nonempty numeric vector)
# [334] -> FAILED (Argument mu must be a nonempty numeric vector)
# [335] -> FAILED (Argument mu must be a nonempty numeric vector)
# [336] -> FAILED (Argument mu must be a nonempty numeric vector)
# [337] -> FAILED (Argument mu must be a nonempty numeric vector)
# [338] -> SKIP (no matching training rows)
# [339] -> FAILED (Argument mu must be a nonempty numeric vector)
# [340] -> SKIP (no matching training rows)
# [341] -> FAILED (Argument mu must be a nonempty numeric vector)
# [342] -> FAILED (Argument mu must be a nonempty numeric vector)
# [351] -> FAILED (Argument mu must be a nonempty numeric vector)
# [352] -> FAILED (Argument mu must be a nonempty numeric vector)
# [353] -> FAILED (Argument mu must be a nonempty numeric vector)
# [354] -> FAILED (Argument mu must be a nonempty numeric vector)
# [355] -> FAILED (Argument mu must be a nonempty numeric vector)
# [356] -> FAILED (Argument mu must be a nonempty numeric vector)
# [357] -> SKIP (no matching training rows)
# [358] -> FAILED (Argument mu must be a nonempty numeric vector)
# [359] -> SKIP (no matching training rows)
# [360] -> FAILED (Argument mu must be a nonempty numeric vector)
# [361] -> FAILED (Argument mu must be a nonempty numeric vector)
# Enron Cleaned | gpt2 -> writing: /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/test/Enron Cleaned/gpt2/idiolect_calibrated_results.xlsx
# Enron Cleaned | gpt2 -> OK

# %%
combined_list <- list()

for (data_type in data_types) {
  for (corpus in corpora) {
    for (model_name in models) {

      # this should point at the *per-combo results file* you want to combine
      file_loc <- file.path(base_loc, data_type, corpus, model_name, save_name)

      prefix <- sprintf("%s | %s | %s", data_type, corpus, model_name)

      if (!file.exists(file_loc)) {
        message(prefix, " -> MISSING: ", file_loc)
        next
      }

      message(prefix, " -> reading: ", file_loc)

      df_i <- tryCatch(
        readxl::read_excel(file_loc),
        error = function(e) {
          message(prefix, " -> FAILED reading (", conditionMessage(e), ")")
          NULL
        }
      )

      if (is.null(df_i) || nrow(df_i) == 0) {
        message(prefix, " -> EMPTY (skipping)")
        next
      }

      # if the file doesn't already include these, add them
      if (!"data_type" %in% names(df_i)) df_i$data_type <- data_type
      if (!"corpus" %in% names(df_i)) df_i$corpus <- corpus
      if (!("scoring_model" %in% names(df_i) || "model_name" %in% names(df_i))) {
        df_i$scoring_model <- model_name
      }

      df_i$source_file <- file_loc

      combined_list[[length(combined_list) + 1]] <- df_i
    }
  }
}

combined_df <- dplyr::bind_rows(combined_list)

combined_save_loc <- file.path(base_loc, combined_save_name)

message("Writing combined file (OVERWRITE): ", combined_save_loc)
writexl::write_xlsx(combined_df, combined_save_loc)
message("DONE. Rows combined: ", nrow(combined_df))
# Out:
# training | Wiki | gpt2 -> reading: /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/training/Wiki/gpt2/idiolect_results.xlsx
# training | Enron | gpt2 -> MISSING: /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/training/Enron/gpt2/idiolect_results.xlsx
# training | Perverted Justice | gpt2 -> MISSING: /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/training/Perverted Justice/gpt2/idiolect_results.xlsx
# training | StackExchange | gpt2 -> MISSING: /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/training/StackExchange/gpt2/idiolect_results.xlsx
# training | ACL | gpt2 -> MISSING: /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/training/ACL/gpt2/idiolect_results.xlsx
# training | TripAdvisor | gpt2 -> MISSING: /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/training/TripAdvisor/gpt2/idiolect_results.xlsx
# training | The Apricity | gpt2 -> MISSING: /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/training/The Apricity/gpt2/idiolect_results.xlsx
# training | Koppel's Blogs | gpt2 -> MISSING: /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/training/Koppel's Blogs/gpt2/idiolect_results.xlsx
# training | The Telegraph | gpt2 -> MISSING: /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/training/The Telegraph/gpt2/idiolect_results.xlsx
# training | Reddit | gpt2 -> MISSING: /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/training/Reddit/gpt2/idiolect_results.xlsx
# training | Enron Cleaned | gpt2 -> reading: /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/training/Enron Cleaned/gpt2/idiolect_results.xlsx
# test | Wiki | gpt2 -> reading: /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/test/Wiki/gpt2/idiolect_results.xlsx
# test | Enron | gpt2 -> MISSING: /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/test/Enron/gpt2/idiolect_results.xlsx
# test | Perverted Justice | gpt2 -> MISSING: /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/test/Perverted Justice/gpt2/idiolect_results.xlsx
# test | StackExchange | gpt2 -> MISSING: /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/test/StackExchange/gpt2/idiolect_results.xlsx
# test | ACL | gpt2 -> MISSING: /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/test/ACL/gpt2/idiolect_results.xlsx
# test | TripAdvisor | gpt2 -> MISSING: /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/test/TripAdvisor/gpt2/idiolect_results.xlsx
# test | The Apricity | gpt2 -> MISSING: /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/test/The Apricity/gpt2/idiolect_results.xlsx
# test | Koppel's Blogs | gpt2 -> MISSING: /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/test/Koppel's Blogs/gpt2/idiolect_results.xlsx
# test | The Telegraph | gpt2 -> MISSING: /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/test/The Telegraph/gpt2/idiolect_results.xlsx
# test | Reddit | gpt2 -> MISSING: /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/test/Reddit/gpt2/idiolect_results.xlsx
# test | Enron Cleaned | gpt2 -> reading: /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/test/Enron Cleaned/gpt2/idiolect_results.xlsx
# Writing combined file (OVERWRITE): /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/raw_idiolect_results_by_context.xlsx
# DONE. Rows combined: 531

# %%
combined_list <- list()

for (corpus in corpora) {
  for (model_name in models) {

    file_loc <- file.path(base_loc, "test", corpus, model_name, calibrated_save_name)
    prefix <- sprintf("test | %s | %s", corpus, model_name)

    if (!file.exists(file_loc)) {
      message(prefix, " -> MISSING: ", file_loc)
      next
    }

    message(prefix, " -> reading: ", file_loc)

    df_i <- tryCatch(
      readxl::read_excel(file_loc),
      error = function(e) {
        message(prefix, " -> FAILED reading (", conditionMessage(e), ")")
        NULL
      }
    )

    if (is.null(df_i) || nrow(df_i) == 0) {
      message(prefix, " -> EMPTY (skipping)")
      next
    }

    # ensure identifiers exist
    if (!"data_type" %in% names(df_i)) df_i$data_type <- "test"
    if (!"corpus" %in% names(df_i)) df_i$corpus <- corpus
    if (!("scoring_model" %in% names(df_i) || "model_name" %in% names(df_i))) {
      df_i$scoring_model <- model_name
    }

    df_i$source_file <- file_loc

    combined_list[[length(combined_list) + 1]] <- df_i
  }
}

combined_calibrated_df <- dplyr::bind_rows(combined_list)

combined_save_loc <- file.path(base_loc, combined_calibrated_save_name)

message("Writing combined calibrated file (OVERWRITE): ", combined_save_loc)
writexl::write_xlsx(combined_calibrated_df, combined_save_loc)
message("DONE. Rows combined: ", nrow(combined_calibrated_df))
# Out:
# test | Wiki | gpt2 -> reading: /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/test/Wiki/gpt2/idiolect_calibrated_results.xlsx
# test | Enron | gpt2 -> MISSING: /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/test/Enron/gpt2/idiolect_calibrated_results.xlsx
# test | Perverted Justice | gpt2 -> MISSING: /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/test/Perverted Justice/gpt2/idiolect_calibrated_results.xlsx
# test | StackExchange | gpt2 -> MISSING: /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/test/StackExchange/gpt2/idiolect_calibrated_results.xlsx
# test | ACL | gpt2 -> MISSING: /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/test/ACL/gpt2/idiolect_calibrated_results.xlsx
# test | TripAdvisor | gpt2 -> MISSING: /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/test/TripAdvisor/gpt2/idiolect_calibrated_results.xlsx
# test | The Apricity | gpt2 -> MISSING: /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/test/The Apricity/gpt2/idiolect_calibrated_results.xlsx
# test | Koppel's Blogs | gpt2 -> MISSING: /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/test/Koppel's Blogs/gpt2/idiolect_calibrated_results.xlsx
# test | The Telegraph | gpt2 -> MISSING: /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/test/The Telegraph/gpt2/idiolect_calibrated_results.xlsx
# test | Reddit | gpt2 -> MISSING: /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/test/Reddit/gpt2/idiolect_calibrated_results.xlsx
# test | Enron Cleaned | gpt2 -> reading: /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/test/Enron Cleaned/gpt2/idiolect_calibrated_results.xlsx
# Writing combined calibrated file (OVERWRITE): /Volumes/BCross/av_datasets_experiments/ngram_masking_logrpobs_n1/raw_idiolect_calibrated_results_by_context.xlsx
# DONE. Rows combined: 266
