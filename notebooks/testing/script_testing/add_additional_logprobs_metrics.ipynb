# %%
import os
import sys
import subprocess
from pathlib import Path

from from_root import from_root

sys.path.insert(0, str(from_root("src")))

from read_and_write_docs import read_rds

# %%
# --- assume notebook is in: n-gram-av-methods/notebooks/script_testing/ ---
REPO_ROOT = Path.cwd().resolve().parents[2]

SCRIPT = REPO_ROOT / "scripts" / "add_additional_logprobs_metrics.py"

PYTHON = REPO_ROOT / "my_venv/bin/python"

# %%
# --- set your args (strings) ---
DATA_LOC = "/Users/user/Downloads/raw_60_phrase_occurrence_score_raw.rds"
SAVE_LOC = "/Users/user/Downloads/raw_60_phrase_occurrence_updated_scores.rds"
INCLUDE_SUMS = True
OVERWRITE = True

# %%
cmd = [
    str(PYTHON), "-u", str(SCRIPT),
    "--data_loc", DATA_LOC,
    "--save_loc", SAVE_LOC,
    "--include_sums",
    "--overwrite"
]

print("Running:\n", " ".join(cmd))
# Out:
# Running:
#  /Users/user/Documents/GitHub/n-gram-av-methods/my_venv/bin/python -u /Users/user/Documents/GitHub/n-gram-av-methods/scripts/add_additional_logprobs_metrics.py --data_loc /Users/user/Downloads/raw_60_phrase_occurrence_score_raw.rds --save_loc /Users/user/Downloads/raw_60_phrase_occurrence_updated_scores.rds --include_sums --overwrite

# %%
# run from repo root so relative paths inside the script behave as expected
proc = subprocess.run(
    cmd,
    cwd=str(REPO_ROOT),
    text=True,
    capture_output=True
)

print(proc.stdout)
if proc.returncode != 0:
    print(proc.stderr)
    raise RuntimeError(f"Script failed with exit code {proc.returncode}")
# Out:
# Reading: /Users/user/Downloads/raw_60_phrase_occurrence_score_raw.rds
# Adding llr_unknown_vs_nocontext
# Creating per-phrase table
# Creating summary by token number
# Saving: /Users/user/Downloads/raw_60_phrase_occurrence_updated_scores.rds
# Done

# %%
read_rds(SAVE_LOC)
# Out:
#      data_type corpus scoring_model  max_context_tokens  \
# 0         test    ACL          gpt2                60.0
# 1         test    ACL          gpt2                60.0
# 2         test    ACL          gpt2                60.0
# 3         test    ACL          gpt2                60.0
# 4         test    ACL          gpt2                60.0
# ...        ...    ...           ...                 ...
# 1316      test    ACL          gpt2                60.0
# 1317      test    ACL          gpt2                60.0
# 1318      test    ACL          gpt2                60.0
# 1319      test    ACL          gpt2                60.0
# 1320      test    ACL          gpt2                60.0
#
#                                                 problem  \
# 0     Ibekwe-SanJuan, Fidelia vs Ibekwe-SanJuan, Fid...
# 1     Ibekwe-SanJuan, Fidelia vs Ibekwe-SanJuan, Fid...
# 2     Ibekwe-SanJuan, Fidelia vs Ibekwe-SanJuan, Fid...
# 3     Ibekwe-SanJuan, Fidelia vs Ibekwe-SanJuan, Fid...
# 4     Ibekwe-SanJuan, Fidelia vs Ibekwe-SanJuan, Fid...
# ...                                                 ...
# 1316           van Noord, Gertjan vs van Noord, Gertjan
# 1317           van Noord, Gertjan vs van Noord, Gertjan
# 1318           van Noord, Gertjan vs van Noord, Gertjan
# 1319           van Noord, Gertjan vs van Noord, Gertjan
# 1320           van Noord, Gertjan vs van Noord, Gertjan
#
#                  known_author           unknown_author  target  completed  \
# 0     Ibekwe-SanJuan, Fidelia  Ibekwe-SanJuan, Fidelia    True       True
# 1     Ibekwe-SanJuan, Fidelia  Ibekwe-SanJuan, Fidelia    True       True
# 2     Ibekwe-SanJuan, Fidelia  Ibekwe-SanJuan, Fidelia    True       True
# 3     Ibekwe-SanJuan, Fidelia  Ibekwe-SanJuan, Fidelia    True       True
# 4     Ibekwe-SanJuan, Fidelia  Ibekwe-SanJuan, Fidelia    True       True
# ...                       ...                      ...     ...        ...
# 1316       van Noord, Gertjan       van Noord, Gertjan    True       True
# 1317       van Noord, Gertjan       van Noord, Gertjan    True       True
# 1318       van Noord, Gertjan       van Noord, Gertjan    True       True
# 1319       van Noord, Gertjan       van Noord, Gertjan    True       True
# 1320       van Noord, Gertjan       van Noord, Gertjan    True       True
#
#       min_token_size  n_rows  no_context_sum_log_probs  unknown_sum_log_probs  \
# 0                1.0   231.0              -3412.582874           -1594.966970
# 1                2.0   127.0              -2015.050190            -970.775691
# 2                3.0    28.0               -600.696632            -328.757965
# 3                4.0     4.0               -123.853603             -97.411926
# 4                5.0     1.0                -43.681000             -38.927950
# ...              ...     ...                       ...                    ...
# 1316             1.0   273.0              -4164.144042           -1687.319801
# 1317             2.0   183.0              -2992.563541           -1247.653011
# 1318             3.0    56.0              -1052.782087            -467.082985
# 1319             4.0    10.0               -207.713557            -109.450900
# 1320             5.0     3.0                -76.019173             -45.701988
#
#       llr_unknown_vs_nocontext  no_context_sum_log_probs_sum  \
# 0                  1817.615904                  -6433.882143
# 1                  1044.274499                  -3555.959951
# 2                   271.938667                   -820.805244
# 3                    26.441677                   -167.534603
# 4                     4.753051                    -87.362000
# ...                        ...                           ...
# 1316               2476.824242                  -9029.452459
# 1317               1744.910530                  -5851.415155
# 1318                585.699102                  -1412.003588
# 1319                 98.262657                   -264.938709
# 1320                 30.317185                    -76.019173
#
#       unknown_sum_log_probs_sum  llr_unknown_vs_nocontext_sum
# 0                  -2906.216016                   3527.666127
# 1                  -1666.116765                   1889.843186
# 2                   -454.684981                    366.120263
# 3                   -136.339875                     31.194728
# 4                    -77.855899                      9.506101
# ...                         ...                           ...
# 1316               -3486.242912                   5543.209547
# 1317               -2363.503475                   3487.911681
# 1318                -616.801966                    795.201621
# 1319                -142.433734                    122.504975
# 1320                 -45.701988                     30.317185
#
# [1321 rows x 17 columns]

# %%
read_rds("/Users/user/Downloads/combined_summary_by_token_num_raw.rds")
# Out:
#       data_type corpus scoring_model  max_context_tokens  \
# 0          test    ACL          gpt2                 0.0
# 1          test    ACL          gpt2                 0.0
# 2          test    ACL          gpt2                 0.0
# 3          test    ACL          gpt2                 0.0
# 4          test    ACL          gpt2                 0.0
# ...         ...    ...           ...                 ...
# 41804  training    ACL          gpt2              1000.0
# 41805  training    ACL          gpt2              1000.0
# 41806  training    ACL          gpt2              1000.0
# 41807  training    ACL          gpt2              1000.0
# 41808  training    ACL          gpt2              1000.0
#
#                                                  problem  \
# 0      Ibekwe-SanJuan, Fidelia vs Ibekwe-SanJuan, Fid...
# 1      Ibekwe-SanJuan, Fidelia vs Ibekwe-SanJuan, Fid...
# 2      Ibekwe-SanJuan, Fidelia vs Ibekwe-SanJuan, Fid...
# 3      Ibekwe-SanJuan, Fidelia vs Ibekwe-SanJuan, Fid...
# 4      Ibekwe-SanJuan, Fidelia vs Ibekwe-SanJuan, Fid...
# ...                                                  ...
# 41804         de Groote, Philippe vs de Groote, Philippe
# 41805         de Groote, Philippe vs de Groote, Philippe
# 41806         de Groote, Philippe vs de Groote, Philippe
# 41807         de Groote, Philippe vs de Groote, Philippe
# 41808         de Groote, Philippe vs de Groote, Philippe
#
#                   known_author           unknown_author  target  completed  \
# 0      Ibekwe-SanJuan, Fidelia  Ibekwe-SanJuan, Fidelia    True       True
# 1      Ibekwe-SanJuan, Fidelia  Ibekwe-SanJuan, Fidelia    True       True
# 2      Ibekwe-SanJuan, Fidelia  Ibekwe-SanJuan, Fidelia    True       True
# 3      Ibekwe-SanJuan, Fidelia  Ibekwe-SanJuan, Fidelia    True       True
# 4      Ibekwe-SanJuan, Fidelia  Ibekwe-SanJuan, Fidelia    True       True
# ...                        ...                      ...     ...        ...
# 41804      de Groote, Philippe      de Groote, Philippe    True       True
# 41805      de Groote, Philippe      de Groote, Philippe    True       True
# 41806      de Groote, Philippe      de Groote, Philippe    True       True
# 41807      de Groote, Philippe      de Groote, Philippe    True       True
# 41808      de Groote, Philippe      de Groote, Philippe    True       True
#
#        min_token_size  n_rows  no_context_sum_log_probs  \
# 0                 1.0   231.0              -3412.582874
# 1                 2.0   127.0              -2015.050190
# 2                 3.0    28.0               -600.696632
# 3                 4.0     4.0               -123.853603
# 4                 5.0     1.0                -43.681000
# ...               ...     ...                       ...
# 41804             4.0     8.0               -317.443123
# 41805             5.0     4.0               -215.571682
# 41806             6.0     3.0               -183.684229
# 41807             8.0     2.0               -155.478905
# 41808            17.0     1.0               -107.909884
#
#        unknown_sum_log_probs  llr_unknown_vs_nocontext  \
# 0               -3412.582874                  0.000000
# 1               -2015.050190                  0.000000
# 2                -600.696632                  0.000000
# 3                -123.853603                  0.000000
# 4                 -43.681000                  0.000000
# ...                      ...                       ...
# 41804            -182.230334                135.212788
# 41805            -138.117354                 77.454329
# 41806            -122.320774                 61.363456
# 41807            -119.551615                 35.927290
# 41808             -88.876562                 19.033322
#
#        no_context_sum_log_probs_sum  unknown_sum_log_probs_sum  \
# 0                      -6433.882143               -6433.882143
# 1                      -3555.959951               -3555.959951
# 2                       -820.805244                -820.805244
# 3                       -167.534603                -167.534603
# 4                        -87.362000                 -87.362000
# ...                             ...                        ...
# 41804                   -394.880695                -195.168847
# 41805                   -271.982331                -143.655672
# 41806                   -240.094878                -127.859091
# 41807                   -155.478905                -119.551615
# 41808                   -107.909884                 -88.876562
#
#        llr_unknown_vs_nocontext_sum
# 0                          0.000000
# 1                          0.000000
# 2                          0.000000
# 3                          0.000000
# 4                          0.000000
# ...                             ...
# 41804                    199.711847
# 41805                    128.326660
# 41806                    112.235787
# 41807                     35.927290
# 41808                     19.033322
#
# [41809 rows x 17 columns]
