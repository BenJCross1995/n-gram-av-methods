# %%
import os
import subprocess
from pathlib import Path

# %%
# --- assume notebook is in: n-gram-av-methods/notebooks/script_testing/ ---
REPO_ROOT = Path.cwd().resolve().parents[2]

SCRIPT = REPO_ROOT / "scripts" / "score_ngrams_multi.py"

PYTHON = REPO_ROOT / "my_venv/bin/python"

# %%
# --- set your args (strings) ---
KNOWN_LOC = "/Volumes/BCross/datasets/author_verification/test/Wiki/known_raw.jsonl"
UNKNOWN_LOC = "/Volumes/BCross/datasets/author_verification/test/Wiki/unknown_raw.jsonl"
METADATA_LOC = "/Volumes/BCross/datasets/author_verification/test/metadata.rds"
MODEL_LOC = "/Volumes/BCross/models/gpt2"
SAVE_LOC = "/Volumes/BCross/av_datasets_experiments/ngram_masking_logprobs_testing"
COMPLETED_LOC = "/Volumes/BCross/av_datasets_experiments/ngram_masking_logprobs_testing2"
CORPUS = "Wiki"
DATA_TYPE = "test"
KNOWN_DOC = "hodja_nasreddin_text_1"
UNKNOWN_DOC = "hodja_nasreddin_text_3"

# %%
cmd = [
    str(PYTHON), "-u", str(SCRIPT),
    "--known_loc", KNOWN_LOC,
    "--unknown_loc", UNKNOWN_LOC,
    "--metadata_loc", METADATA_LOC,
    "--model_loc", MODEL_LOC,
    "--save_loc", SAVE_LOC,
    "--completed_loc", COMPLETED_LOC,
    "--corpus", CORPUS,
    "--data_type", DATA_TYPE,
    "--known_doc", KNOWN_DOC,
    "--unknown_doc", UNKNOWN_DOC,
    "--ngram_n", str(1)
]

print("Running:\n", " ".join(cmd))
# Out:
# Running:
#  /Users/user/Documents/GitHub/n-gram-av-methods/my_venv/bin/python -u /Users/user/Documents/GitHub/n-gram-av-methods/scripts/score_ngrams_multi.py --known_loc /Volumes/BCross/datasets/author_verification/test/Wiki/known_raw.jsonl --unknown_loc /Volumes/BCross/datasets/author_verification/test/Wiki/unknown_raw.jsonl --metadata_loc /Volumes/BCross/datasets/author_verification/test/metadata.rds --model_loc /Volumes/BCross/models/gpt2 --save_loc /Volumes/BCross/av_datasets_experiments/ngram_masking_logprobs_testing --completed_loc /Volumes/BCross/av_datasets_experiments/ngram_masking_logprobs_testing2 --corpus Wiki --data_type test --known_doc hodja_nasreddin_text_1 --unknown_doc hodja_nasreddin_text_3 --ngram_n 1

# %%
# run from repo root so relative paths inside the script behave as expected
proc = subprocess.run(
    cmd,
    cwd=str(REPO_ROOT),
    text=True,
    capture_output=True
)

print(proc.stdout)
if proc.returncode != 0:
    print(proc.stderr)
    raise RuntimeError(f"Script failed with exit code {proc.returncode}")
# Out:
# ---------------------------------------------------------------------------
#
# KeyboardInterrupt                         Traceback (most recent call last)
#
# Cell In[15], line 2
#
#       1 # run from repo root so relative paths inside the script behave as expected
#
# ----> 2 proc = subprocess.run(
#
#       3     cmd,
#
#       4     cwd=str(REPO_ROOT),
#
#       5     text=True,
#
#       6     capture_output=True
#
#       7 )
#
#       9 print(proc.stdout)
#
#      10 if proc.returncode != 0:
#
#
#
# File /opt/homebrew/Cellar/python@3.11/3.11.7_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/subprocess.py:550, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#
#     548 with Popen(*popenargs, **kwargs) as process:
#
#     549     try:
#
# --> 550         stdout, stderr = process.communicate(input, timeout=timeout)
#
#     551     except TimeoutExpired as exc:
#
#     552         process.kill()
#
#
#
# File /opt/homebrew/Cellar/python@3.11/3.11.7_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/subprocess.py:1209, in Popen.communicate(self, input, timeout)
#
#    1206     endtime = None
#
#    1208 try:
#
# -> 1209     stdout, stderr = self._communicate(input, endtime, timeout)
#
#    1210 except KeyboardInterrupt:
#
#    1211     # https://bugs.python.org/issue25942
#
#    1212     # See the detailed comment in .wait().
#
#    1213     if timeout is not None:
#
#
#
# File /opt/homebrew/Cellar/python@3.11/3.11.7_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/subprocess.py:2108, in Popen._communicate(self, input, endtime, orig_timeout)
#
#    2101     self._check_timeout(endtime, orig_timeout,
#
#    2102                         stdout, stderr,
#
#    2103                         skip_check_and_raise=True)
#
#    2104     raise RuntimeError(  # Impossible :)
#
#    2105         '_check_timeout(..., skip_check_and_raise=True) '
#
#    2106         'failed to raise TimeoutExpired.')
#
# -> 2108 ready = selector.select(timeout)
#
#    2109 self._check_timeout(endtime, orig_timeout, stdout, stderr)
#
#    2111 # XXX Rewrite these to use non-blocking I/O on the file
#
#    2112 # objects; they are no longer using C stdio!
#
#
#
# File /opt/homebrew/Cellar/python@3.11/3.11.7_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/selectors.py:415, in _PollLikeSelector.select(self, timeout)
#
#     413 ready = []
#
#     414 try:
#
# --> 415     fd_event_list = self._selector.poll(timeout)
#
#     416 except InterruptedError:
#
#     417     return ready
#
#
#
# KeyboardInterrupt:
