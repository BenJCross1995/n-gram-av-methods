# %%
import os
import subprocess
from pathlib import Path

# %%
# --- assume notebook is in: n-gram-av-methods/notebooks/script_testing/ ---
REPO_ROOT = Path.cwd().resolve().parents[2]

SCRIPT = REPO_ROOT / "scripts" / "score_ngrams_multi.py"

PYTHON = REPO_ROOT / "my_venv/bin/python"

# %%
# --- set your args (strings) ---
base_loc = "/Volumes/BCross"

if not os.path.exists(base_loc):
    print("Using Offline Location")
    base_loc = "/Users/user/Documents/uni_work_offline"
else:
    print("Using Volume Location")

KNOWN_LOC = f"{base_loc}/datasets/author_verification/test/Wiki/known_raw.jsonl"
UNKNOWN_LOC = f"{base_loc}/datasets/author_verification/test/Wiki/unknown_raw.jsonl"
METADATA_LOC = f"{base_loc}/datasets/author_verification/test/metadata.rds"
MODEL_LOC = f"{base_loc}/models/gpt2"
SAVE_LOC = f"{base_loc}/av_datasets_experiments/concat_ngram_masking_logprobs_testing"
COMPLETED_LOC = f"{base_loc}/av_datasets_experiments/concat_ngram_masking_logprobs_testing"
CORPUS = "Wiki"
DATA_TYPE = "test"
PROBLEM = "Hodja_Nasreddin vs Hodja_Nasreddin"
SCORE_SCRIPT = "score_ngrams_concat"
# Out:
# Using Offline Location

# %%
cmd = [
    str(PYTHON), "-u", str(SCRIPT),
    "--known_loc", KNOWN_LOC,
    "--unknown_loc", UNKNOWN_LOC,
    "--metadata_loc", METADATA_LOC,
    "--model_loc", MODEL_LOC,
    "--save_loc", SAVE_LOC,
    "--completed_loc", COMPLETED_LOC,
    "--corpus", CORPUS,
    "--data_type", DATA_TYPE,
    "--problem", PROBLEM,
    "--score_script", "score_ngrams_concat"
]

print("Running:\n", " ".join(cmd))
# Out:
# Running:
#  /Users/user/Documents/GitHub/n-gram-av-methods/my_venv/bin/python -u /Users/user/Documents/GitHub/n-gram-av-methods/scripts/score_ngrams_multi.py --known_loc /Users/user/Documents/uni_work_offline/datasets/author_verification/test/Wiki/known_raw.jsonl --unknown_loc /Users/user/Documents/uni_work_offline/datasets/author_verification/test/Wiki/unknown_raw.jsonl --metadata_loc /Users/user/Documents/uni_work_offline/datasets/author_verification/test/metadata.rds --model_loc /Users/user/Documents/uni_work_offline/models/gpt2 --save_loc /Users/user/Documents/uni_work_offline/av_datasets_experiments/concat_ngram_masking_logprobs_testing --completed_loc /Users/user/Documents/uni_work_offline/av_datasets_experiments/concat_ngram_masking_logprobs_testing --corpus Wiki --data_type test --problem Hodja_Nasreddin vs Hodja_Nasreddin --score_script score_ngrams_concat

# %%
# run from repo root so relative paths inside the script behave as expected
proc = subprocess.run(
    cmd,
    cwd=str(REPO_ROOT),
    text=True,
    capture_output=True
)

print(proc.stdout)
if proc.returncode != 0:
    print(proc.stderr)
    raise RuntimeError(f"Script failed with exit code {proc.returncode}")
# Out:
# ================================================================================
# Running: num_tokens=10
# Command: /Users/user/Documents/GitHub/n-gram-av-methods/my_venv/bin/python /Users/user/Documents/GitHub/n-gram-av-methods/scripts/score_ngrams_concat.py --known_loc /Users/user/Documents/uni_work_offline/datasets/author_verification/test/Wiki/known_raw.jsonl --unknown_loc /Users/user/Documents/uni_work_offline/datasets/author_verification/test/Wiki/unknown_raw.jsonl --metadata_loc /Users/user/Documents/uni_work_offline/datasets/author_verification/test/metadata.rds --model_loc /Users/user/Documents/uni_work_offline/models/gpt2 --corpus Wiki --data_type test --problem Hodja_Nasreddin vs Hodja_Nasreddin --save_loc /Users/user/Documents/uni_work_offline/av_datasets_experiments/concat_ngram_masking_logprobs_testing_10 --completed_loc /Users/user/Documents/uni_work_offline/av_datasets_experiments/concat_ngram_masking_logprobs_testing_10 --num_tokens 10
# ================================================================================
# Working on problem: Hodja_Nasreddin vs Hodja_Nasreddin
# Loading model
# Loading data
# Data loaded
# There are 3 known texts in the problem
# Getting common n-grams
# Working on doc 1
# Working on doc 2
# Working on doc 3
# There are 115 n-grams in common!
# Scoring the No Context n-grams
# Scoring the Unknown n-grams
#
# ================================================================================
# Running: num_tokens=20
# Command: /Users/user/Documents/GitHub/n-gram-av-methods/my_venv/bin/python /Users/user/Documents/GitHub/n-gram-av-methods/scripts/score_ngrams_concat.py --known_loc /Users/user/Documents/uni_work_offline/datasets/author_verification/test/Wiki/known_raw.jsonl --unknown_loc /Users/user/Documents/uni_work_offline/datasets/author_verification/test/Wiki/unknown_raw.jsonl --metadata_loc /Users/user/Documents/uni_work_offline/datasets/author_verification/test/metadata.rds --model_loc /Users/user/Documents/uni_work_offline/models/gpt2 --corpus Wiki --data_type test --problem Hodja_Nasreddin vs Hodja_Nasreddin --save_loc /Users/user/Documents/uni_work_offline/av_datasets_experiments/concat_ngram_masking_logprobs_testing_20 --completed_loc /Users/user/Documents/uni_work_offline/av_datasets_experiments/concat_ngram_masking_logprobs_testing_20 --num_tokens 20
# ================================================================================
# Working on problem: Hodja_Nasreddin vs Hodja_Nasreddin
# Loading model
# Loading data
# Data loaded
# There are 3 known texts in the problem
# Getting common n-grams
# Working on doc 1
# Working on doc 2
# Working on doc 3
# There are 115 n-grams in common!
# Scoring the No Context n-grams
# Scoring the Unknown n-grams
#
# ================================================================================
# Running: num_tokens=30
# Command: /Users/user/Documents/GitHub/n-gram-av-methods/my_venv/bin/python /Users/user/Documents/GitHub/n-gram-av-methods/scripts/score_ngrams_concat.py --known_loc /Users/user/Documents/uni_work_offline/datasets/author_verification/test/Wiki/known_raw.jsonl --unknown_loc /Users/user/Documents/uni_work_offline/datasets/author_verification/test/Wiki/unknown_raw.jsonl --metadata_loc /Users/user/Documents/uni_work_offline/datasets/author_verification/test/metadata.rds --model_loc /Users/user/Documents/uni_work_offline/models/gpt2 --corpus Wiki --data_type test --problem Hodja_Nasreddin vs Hodja_Nasreddin --save_loc /Users/user/Documents/uni_work_offline/av_datasets_experiments/concat_ngram_masking_logprobs_testing_30 --completed_loc /Users/user/Documents/uni_work_offline/av_datasets_experiments/concat_ngram_masking_logprobs_testing_30 --num_tokens 30
# ================================================================================
# Working on problem: Hodja_Nasreddin vs Hodja_Nasreddin
# Loading model
# Loading data
# Data loaded
# There are 3 known texts in the problem
# Getting common n-grams
# Working on doc 1
# Working on doc 2
# Working on doc 3
# There are 115 n-grams in common!
# Scoring the No Context n-grams
# Scoring the Unknown n-grams
#
# ================================================================================
# Running: num_tokens=40
# Command: /Users/user/Documents/GitHub/n-gram-av-methods/my_venv/bin/python /Users/user/Documents/GitHub/n-gram-av-methods/scripts/score_ngrams_concat.py --known_loc /Users/user/Documents/uni_work_offline/datasets/author_verification/test/Wiki/known_raw.jsonl --unknown_loc /Users/user/Documents/uni_work_offline/datasets/author_verification/test/Wiki/unknown_raw.jsonl --metadata_loc /Users/user/Documents/uni_work_offline/datasets/author_verification/test/metadata.rds --model_loc /Users/user/Documents/uni_work_offline/models/gpt2 --corpus Wiki --data_type test --problem Hodja_Nasreddin vs Hodja_Nasreddin --save_loc /Users/user/Documents/uni_work_offline/av_datasets_experiments/concat_ngram_masking_logprobs_testing_40 --completed_loc /Users/user/Documents/uni_work_offline/av_datasets_experiments/concat_ngram_masking_logprobs_testing_40 --num_tokens 40
# ================================================================================
# Working on problem: Hodja_Nasreddin vs Hodja_Nasreddin
# Loading model
# Loading data
# Data loaded
# There are 3 known texts in the problem
# Getting common n-grams
# Working on doc 1
# Working on doc 2
# Working on doc 3
# There are 115 n-grams in common!
# Scoring the No Context n-grams
# Scoring the Unknown n-grams
#
# ================================================================================
# Running: num_tokens=50
# Command: /Users/user/Documents/GitHub/n-gram-av-methods/my_venv/bin/python /Users/user/Documents/GitHub/n-gram-av-methods/scripts/score_ngrams_concat.py --known_loc /Users/user/Documents/uni_work_offline/datasets/author_verification/test/Wiki/known_raw.jsonl --unknown_loc /Users/user/Documents/uni_work_offline/datasets/author_verification/test/Wiki/unknown_raw.jsonl --metadata_loc /Users/user/Documents/uni_work_offline/datasets/author_verification/test/metadata.rds --model_loc /Users/user/Documents/uni_work_offline/models/gpt2 --corpus Wiki --data_type test --problem Hodja_Nasreddin vs Hodja_Nasreddin --save_loc /Users/user/Documents/uni_work_offline/av_datasets_experiments/concat_ngram_masking_logprobs_testing_50 --completed_loc /Users/user/Documents/uni_work_offline/av_datasets_experiments/concat_ngram_masking_logprobs_testing_50 --num_tokens 50
# ================================================================================
# Working on problem: Hodja_Nasreddin vs Hodja_Nasreddin
# Loading model
# Loading data
# Data loaded
# There are 3 known texts in the problem
# Getting common n-grams
# Working on doc 1
# Working on doc 2
# Working on doc 3
# There are 115 n-grams in common!
# Scoring the No Context n-grams
# Scoring the Unknown n-grams
#
# All runs completed successfully.
